# %%
pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.6.2-py3-none-any.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 5.1 MB/s
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.6.2

# %%
pip install gingerit
# Out:
# Collecting gingerit
#   Downloading gingerit-0.8.2-py3-none-any.whl (3.3 kB)
# Collecting requests<3.0.0,>=2.25.1
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.3 MB/s
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.1->gingerit) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.1->gingerit) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.1->gingerit) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.1->gingerit) (2.0.9)
# Installing collected packages: requests, gingerit
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed gingerit-0.8.2 requests-2.27.1

# %%
from gingerit.gingerit import GingerIt
from spellchecker import SpellChecker

# %% [markdown]
# ## Construction of English Grammar
#
# Input : English Grammar specifications file
#
# Output : Grammar object
#
# -> English Grammar string processing
#
# -> Construction of Grammar class

# %%
# READING GRAMMAR SPECIFICATIONS

inputFile = open('grammar.txt', 'r')
inputText = inputFile.read()
grammarRules = [ rule.strip() for rule in inputText.split("\n")]
grammarRules
# Out:
# ['S -> NP_SG PAST S1 | NP_SG PAST_PERFECT S1 | NP_SG PAST_CONT_SG S1 | NP_SG PAST_PERFECT_CONT S1 | NP_SG PRES_SG S1 | NP_SG PRES_PERFECT_SG S1 | NP_SG PRES_CONT_SG S1 | NP_SG PRES_PERFECT_CONT_SG S1 | NP_SG FUTURE S1 | NP_SG FUTURE_PERFECT S1 | NP_SG FUTURE_CONT S1 | NP_SG FUTURE_PERFECT_CONT S1 | NP_PL PAST S1 | NP_PL PAST_PERFECT S1 | NP_PL PAST_CONT_PL S1 | NP_PL PAST_PERFECT_CONT S1 | NP_PL PRES_PL S1  | NP_PL PRES_PERFECT_PL S1 | NP_PL PRES_CONT_PL S1 | NP_PL PRES_PERFECT_CONT_PL S1 | NP_PL FUTURE S1 | NP_PL FUTURE_PERFECT S1 | NP_PL FUTURE_CONT S1 | NP_PL FUTURE_PERFECT_CONT S1 | S ADV',
#  'S1 -> NP | ADV',
#  'NP -> NP_SG | NP_PL | PP | NP PP',
#  'NP_SG ->  PRONOUN_SG | PRONOUN_SG NOM_SG| PROPERNOUN | NOM_SG | DET_SG NOM_SG | DET_BOTH NOM_SG | ADV NP_SG | NP_SG CONJ NP',
#  'NOM_SG -> NOUN_SG | ADJ NOUN_SG | NOM_SG NOUN_SG',
#  'NP_PL -> PRONOUN_PL | PRONOUN_PL NOM_PL| NOM_PL | DET_PL NOM_PL | DET_BOTH NOM_PL | ADV NP_PL | NP_PL CONJ NP',
#  'NOM_PL -> NOUN_PL | ADJ NOUN_PL | NOM_PL NOUN_PL',
#  'PP -> PREPOS NP_SG | PREPOS NP_PL',
#  'PAST -> V2 | ADV V2',
#  'PAST_PERFECT -> had V3 | had ADV V3',
#  'PAST_CONT_SG -> was GERUNDV | was ADV GERUNDV',
#  'PAST_CONT_PL -> were GERUNDV | were ADV GERUNDV',
#  'PAST_PERFECT_CONT -> had been GERUNDV | had ADV been GERUNDV',
#  'PRES_SG -> V1_SG | ADV V1_SG',
#  'PRES_PL -> V1_PL | ADV V1_PL',
#  'PRES_PERFECT_SG -> has V3 | has ADV V3',
#  'PRES_PERFECT_PL -> have V3 | have ADV V3',
#  'PRES_CONT_SG -> is GERUNDV | is ADV GERUNDV',
#  'PRES_CONT_PL -> are GERUNDV | are ADV GERUNDV',
#  'PRES_PERFECT_CONT_SG -> has been GERUNDV | has ADV been GERUNDV | has been | has ADV been',
#  'PRES_PERFECT_CONT_PL -> have been GERUNDV | have ADV been GERUNDV',
#  'FUTURE -> will V1_PL | will ADV V1_PL',
#  'FUTURE_PERFECT -> will have V3 | will have ADV V3',
#  'FUTURE_CONT -> will be GERUNDV | will ADV be GERUNDV',
#  'FUTURE_PERFECT_CONT -> will have been GERUNDV | will have ADV been GERUNDV',
#  'PRONOUN_SG -> my | she | he | it | him | i | her | his',
#  'PRONOUN_PL -> they | us | you | we | their',
#  'RELPR_SG -> which',
#  'RELPR_PL -> whom',
#  'PROPERNOUN -> ishwarya | joseph | india | germany | ajitesh | navvya | ritheesh | switzerland | paris | wednesday | january | may | turkey | easter | november | raj | canada | america | john',
#  'NOUN_SG -> sentence | me | kabaddi | friend | patient | parcel | player | moment | morning | grandfather | outlet | evening | programming | building | thinking | mom | weekend | brother | basketball | afternoon | book | accountant | milk | accident | neighbourhood | car | phone | night | airplane | fog | street | dad | bed | fire | house | zoo | cold | pope | cup | sister | party | tea | weather | call | baby | movie | picture | pilot | airport | assignment | week | month | room | homework | husband | year | school | teacher | letter | football | food | mountain | wife | topper | song | show | garden | album',
#  'NOUN_PL -> roses | mountains | goats | films | times | emails | people | children |  specialists | girls | parents | jacksons | cows | boys | books | years | portraits | friends | ages | weeks | letters | peacocks | books',
#  'DET_SG -> a | an | this | that',
#  'DET_PL -> these | all | many | no',
#  'DET_BOTH -> the',
#  'CONJ -> and | but | because | while',
#  'ADJ -> red | delicious | first | few | two | four | three | fun | since | sweet | nice | severe | terrible | hungry | new | whole | last | every | critical',
#  'ADV -> well | gracefully | before | next | very | when | not | whereabouts | constantly | lately | yesterday | ago | tomorrow | early | still | twice | always | already | past | never | today | never | recently | heavily',
#  'PREPOS -> at | in | of | for | by | from | far | on | around | as | to | down',
#  'V1_SG -> climbs | teaches | plays | cooks | is | likes | be | know | am | draws | works | understands | invloves | sings',
#  'V1_PL -> teach | are | sing | give | think | rain | turn | go | see | do | take | study | speak | drink | cook | meet',
#  'GERUNDV -> teaching | running | writing | opening | burning | feeling | enjoying | living | spending | ringing | repairing | visiting | having | climbing | getting | meeting | playing | cleaning | going | looking | suffering | raining | waiting | studying | snowing | seeing | dating | taking | listening | dancing',
#  'V2 -> taught | were | was | went | knew | would | started | received | gave | caught | married | understood | flew | drink | read | made | tired | saw | did',
#  'V3 -> seen | written | given | done | gone | made | flown | painted | fed | met | finished | acted | watched']

# %%
class Grammar :
  def __init__(self, grammarStr) :
    self.input = grammarStr
    self.symbols = set()
    self.terminals = set()
    self.nonterminals = set()
    self.startSymbol = None
    self.grammar = {}

    for production in grammarStr :
      # The partition() method searches for a specified string, and splits the string into a tuple containing three elements.
      head, _, bodies = production.partition(' -> ')
      
      # The nonterminal of the first production is considered to be the start symbol
      if self.startSymbol is None :
        self.startSymbol = head

      self.grammar.setdefault(head, set())
      self.nonterminals.add(head)

      bodies = {tuple(body.strip().split(" ")) for body in ' '.join(bodies.split(" ")).split('|') }

      for body in bodies :
        self.grammar[head].add(body)
        for symbol in body :
          if symbol.isupper() :
            self.nonterminals.add(symbol)
          else :
            self.terminals.add(symbol)  
    
    self.symbols = self.nonterminals | self.terminals

  def __str__ (self) :
    print("Start Symbol : " , self.startSymbol)
    print("Non-terminals : " , self.nonterminals)
    print("Terminals : " , self.terminals)
    print("Productions : ")
    for head in self.grammar :
      for body in self.grammar[head] :
        print(head, "->", body)
    return ""

# %%
G = Grammar(grammarRules)
print(G)
properNouns = set()
for pn in G.grammar["PROPERNOUN"]:
  for noun in pn :
    properNouns.add(noun)
# Out:
# Start Symbol :  S
# Non-terminals :  {'PAST_CONT_SG', 'NOUN_SG', 'NOM_SG', 'RELPR_SG', 'NOM_PL', 'GERUNDV', 'PAST_CONT_PL', 'DET_SG', 'PAST', 'DET_BOTH', 'PRONOUN_SG', 'PRES_PERFECT_SG', 'V1_PL', 'V3', 'RELPR_PL', 'NP', 'FUTURE', 'PROPERNOUN', 'FUTURE_PERFECT', 'PREPOS', 'S1', 'NOUN_PL', 'ADV', 'FUTURE_PERFECT_CONT', 'PRES_PERFECT_PL', 'V2', 'PAST_PERFECT_CONT', 'PRES_PERFECT_CONT_PL', 'V1_SG', 'CONJ', 'PP', 'S', 'PAST_PERFECT', 'ADJ', 'PRES_PL', 'PRES_CONT_PL', 'PRES_PERFECT_CONT_SG', 'PRES_SG', 'PRONOUN_PL', 'NP_SG', 'DET_PL', 'FUTURE_CONT', 'PRES_CONT_SG', 'NP_PL'}
# Terminals :  {'afternoon', 'car', 'tomorrow', 'ritheesh', 'cup', 'by', 'meet', 'snowing', 'today', 'understands', 'caught', 'dad', 'weather', 'were', 'raj', 'climbing', 'bed', 'am', 'zoo', 'we', 'january', 'you', 'know', 'ringing', 'sweet', 'opening', 'few', 'suffering', 'mountains', 'people', 'morning', 'book', 'us', 'these', 'yesterday', 'teaches', 'boys', 'turkey', 'seeing', 'ago', 'give', 'books', 'getting', 'far', 'ages', 'visiting', 'received', 'football', 'room', 'garden', 'watched', 'of', 'take', 'whom', 'the', 'down', 'still', 'taught', 'three', 'finished', 'november', 'will', 'always', 'my', 'mom', 'as', 'sister', 'that', 'having', 'read', 'see', 'had', 'meeting', 'dating', 'ajitesh', 'works', 'flew', 'parcel', 'looking', 'listening', 'burning', 'evening', 'twice', 'are', 'children', 'pilot', 'teacher', 'gone', 'india', 'accountant', 'phone', 'critical', 'topper', 'feeling', 'canada', 'living', 'already', 'seen', 'to', 'fun', 'america', 'made', 'they', 'parents', 'drink', 'album', 'navvya', 'goats', 'gracefully', 'from', 'this', 'started', 'done', 'teaching', 'but', 'moment', 'i', 'saw', 'tea', 'school', 'portraits', 'go', 'all', 'milk', 'friend', 'she', 'programming', 'never', 'john', 'first', 'patient', 'running', 'written', 'may', 'have', 'many', 'whole', 'airport', 'taking', 'is', 'and', 'think', 'invloves', 'study', 'airplane', 'year', 'hungry', 'on', 'sings', 'player', 'new', 'picture', 'recently', 'studying', 'weeks', 'climbs', 'rain', 'cows', 'met', 'be', 'constantly', 'would', 'an', 'paris', 'severe', 'not', 'flown', 'because', 'month', 'cleaning', 'ishwarya', 'last', 'gave', 'emails', 'painted', 'two', 'lately', 'has', 'he', 'waiting', 'cooks', 'their', 'movie', 'basketball', 'every', 'when', 'tired', 'baby', 'draws', 'writing', 'was', 'spending', 'night', 'early', 'thinking', 'teach', 'letters', 'kabaddi', 'dancing', 'been', 'it', 'heavily', 'at', 'house', 'fire', 'raining', 'playing', 'fog', 'germany', 'easter', 'terrible', 'married', 'enjoying', 'switzerland', 'his', 'wednesday', 'given', 'outlet', 'very', 'speak', 'nice', 'past', 'times', 'grandfather', 'films', 'peacocks', 'her', 'knew', 'cook', 'food', 'fed', 'next', 'me', 'plays', 'sentence', 'call', 'turn', 'accident', 'sing', 'years', 'no', 'him', 'whereabouts', 'well', 'song', 'week', 'did', 'acted', 'show', 'around', 'do', 'before', 'specialists', 'girls', 'while', 'jacksons', 'weekend', 'likes', 'homework', 'since', 'neighbourhood', 'letter', 'roses', 'delicious', 'joseph', 'mountain', 'party', 'wife', 'repairing', 'four', 'going', 'brother', 'building', 'red', 'went', 'a', 'street', 'which', 'for', 'assignment', 'husband', 'pope', 'in', 'friends', 'understood', 'cold'}
# Productions :
# S -> ('NP_SG', 'FUTURE_PERFECT', 'S1')
# S -> ('S', 'ADV')
# S -> ('NP_PL', 'PAST_PERFECT_CONT', 'S1')
# S -> ('NP_PL', 'FUTURE_PERFECT', 'S1')
# S -> ('NP_SG', 'PAST_CONT_SG', 'S1')
# S -> ('NP_SG', 'FUTURE_CONT', 'S1')
# S -> ('NP_PL', 'PAST', 'S1')
# S -> ('NP_PL', 'PAST_PERFECT', 'S1')
# S -> ('NP_PL', 'FUTURE', 'S1')
# S -> ('NP_PL', 'PAST_CONT_PL', 'S1')
# S -> ('NP_SG', 'PRES_CONT_SG', 'S1')
# S -> ('NP_SG', 'FUTURE_PERFECT_CONT', 'S1')
# S -> ('NP_SG', 'PAST', 'S1')
# S -> ('NP_PL', 'PRES_CONT_PL', 'S1')
# S -> ('NP_SG', 'PRES_PERFECT_CONT_SG', 'S1')
# S -> ('NP_PL', 'PRES_PERFECT_PL', 'S1')
# S -> ('NP_PL', 'FUTURE_PERFECT_CONT', 'S1')
# S -> ('NP_SG', 'FUTURE', 'S1')
# S -> ('NP_SG', 'PAST_PERFECT', 'S1')
# S -> ('NP_PL', 'PRES_PL', 'S1')
# S -> ('NP_SG', 'PRES_PERFECT_SG', 'S1')
# S -> ('NP_PL', 'FUTURE_CONT', 'S1')
# S -> ('NP_PL', 'PRES_PERFECT_CONT_PL', 'S1')
# S -> ('NP_SG', 'PAST_PERFECT_CONT', 'S1')
# S -> ('NP_SG', 'PRES_SG', 'S1')
# S1 -> ('ADV',)
# S1 -> ('NP',)
# NP -> ('PP',)
# NP -> ('NP_SG',)
# NP -> ('NP', 'PP')
# NP -> ('NP_PL',)
# NP_SG -> ('DET_SG', 'NOM_SG')
# NP_SG -> ('PRONOUN_SG',)
# NP_SG -> ('NOM_SG',)
# NP_SG -> ('PRONOUN_SG', 'NOM_SG')
# NP_SG -> ('DET_BOTH', 'NOM_SG')
# NP_SG -> ('ADV', 'NP_SG')
# NP_SG -> ('PROPERNOUN',)
# NP_SG -> ('NP_SG', 'CONJ', 'NP')
# NOM_SG -> ('NOM_SG', 'NOUN_SG')
# NOM_SG -> ('ADJ', 'NOUN_SG')
# NOM_SG -> ('NOUN_SG',)
# NP_PL -> ('NP_PL', 'CONJ', 'NP')
# NP_PL -> ('PRONOUN_PL', 'NOM_PL')
# NP_PL -> ('NOM_PL',)
# NP_PL -> ('PRONOUN_PL',)
# NP_PL -> ('DET_PL', 'NOM_PL')
# NP_PL -> ('ADV', 'NP_PL')
# NP_PL -> ('DET_BOTH', 'NOM_PL')
# NOM_PL -> ('NOUN_PL',)
# NOM_PL -> ('ADJ', 'NOUN_PL')
# NOM_PL -> ('NOM_PL', 'NOUN_PL')
# PP -> ('PREPOS', 'NP_SG')
# PP -> ('PREPOS', 'NP_PL')
# PAST -> ('V2',)
# PAST -> ('ADV', 'V2')
# PAST_PERFECT -> ('had', 'V3')
# PAST_PERFECT -> ('had', 'ADV', 'V3')
# PAST_CONT_SG -> ('was', 'GERUNDV')
# PAST_CONT_SG -> ('was', 'ADV', 'GERUNDV')
# PAST_CONT_PL -> ('were', 'ADV', 'GERUNDV')
# PAST_CONT_PL -> ('were', 'GERUNDV')
# PAST_PERFECT_CONT -> ('had', 'ADV', 'been', 'GERUNDV')
# PAST_PERFECT_CONT -> ('had', 'been', 'GERUNDV')
# PRES_SG -> ('V1_SG',)
# PRES_SG -> ('ADV', 'V1_SG')
# PRES_PL -> ('V1_PL',)
# PRES_PL -> ('ADV', 'V1_PL')
# PRES_PERFECT_SG -> ('has', 'ADV', 'V3')
# PRES_PERFECT_SG -> ('has', 'V3')
# PRES_PERFECT_PL -> ('have', 'ADV', 'V3')
# PRES_PERFECT_PL -> ('have', 'V3')
# PRES_CONT_SG -> ('is', 'ADV', 'GERUNDV')
# PRES_CONT_SG -> ('is', 'GERUNDV')
# PRES_CONT_PL -> ('are', 'GERUNDV')
# PRES_CONT_PL -> ('are', 'ADV', 'GERUNDV')
# PRES_PERFECT_CONT_SG -> ('has', 'been', 'GERUNDV')
# PRES_PERFECT_CONT_SG -> ('has', 'ADV', 'been')
# PRES_PERFECT_CONT_SG -> ('has', 'ADV', 'been', 'GERUNDV')
# PRES_PERFECT_CONT_SG -> ('has', 'been')
# PRES_PERFECT_CONT_PL -> ('have', 'been', 'GERUNDV')
# PRES_PERFECT_CONT_PL -> ('have', 'ADV', 'been', 'GERUNDV')
# FUTURE -> ('will', 'V1_PL')
# FUTURE -> ('will', 'ADV', 'V1_PL')
# FUTURE_PERFECT -> ('will', 'have', 'V3')
# FUTURE_PERFECT -> ('will', 'have', 'ADV', 'V3')
# FUTURE_CONT -> ('will', 'be', 'GERUNDV')
# FUTURE_CONT -> ('will', 'ADV', 'be', 'GERUNDV')
# FUTURE_PERFECT_CONT -> ('will', 'have', 'ADV', 'been', 'GERUNDV')
# FUTURE_PERFECT_CONT -> ('will', 'have', 'been', 'GERUNDV')
# PRONOUN_SG -> ('my',)
# PRONOUN_SG -> ('she',)
# PRONOUN_SG -> ('him',)
# PRONOUN_SG -> ('he',)
# PRONOUN_SG -> ('his',)
# PRONOUN_SG -> ('her',)
# PRONOUN_SG -> ('it',)
# PRONOUN_SG -> ('i',)
# PRONOUN_PL -> ('us',)
# PRONOUN_PL -> ('we',)
# PRONOUN_PL -> ('their',)
# PRONOUN_PL -> ('you',)
# PRONOUN_PL -> ('they',)
# RELPR_SG -> ('which',)
# RELPR_PL -> ('whom',)
# PROPERNOUN -> ('india',)
# PROPERNOUN -> ('germany',)
# PROPERNOUN -> ('january',)
# PROPERNOUN -> ('john',)
# PROPERNOUN -> ('ajitesh',)
# PROPERNOUN -> ('switzerland',)
# PROPERNOUN -> ('paris',)
# PROPERNOUN -> ('canada',)
# PROPERNOUN -> ('easter',)
# PROPERNOUN -> ('wednesday',)
# PROPERNOUN -> ('november',)
# PROPERNOUN -> ('joseph',)
# PROPERNOUN -> ('ishwarya',)
# PROPERNOUN -> ('america',)
# PROPERNOUN -> ('ritheesh',)
# PROPERNOUN -> ('navvya',)
# PROPERNOUN -> ('turkey',)
# PROPERNOUN -> ('may',)
# PROPERNOUN -> ('raj',)
# NOUN_SG -> ('grandfather',)
# NOUN_SG -> ('letter',)
# NOUN_SG -> ('tea',)
# NOUN_SG -> ('programming',)
# NOUN_SG -> ('fog',)
# NOUN_SG -> ('accountant',)
# NOUN_SG -> ('phone',)
# NOUN_SG -> ('airplane',)
# NOUN_SG -> ('accident',)
# NOUN_SG -> ('building',)
# NOUN_SG -> ('room',)
# NOUN_SG -> ('year',)
# NOUN_SG -> ('evening',)
# NOUN_SG -> ('movie',)
# NOUN_SG -> ('school',)
# NOUN_SG -> ('patient',)
# NOUN_SG -> ('dad',)
# NOUN_SG -> ('bed',)
# NOUN_SG -> ('pope',)
# NOUN_SG -> ('zoo',)
# NOUN_SG -> ('fire',)
# NOUN_SG -> ('album',)
# NOUN_SG -> ('milk',)
# NOUN_SG -> ('party',)
# NOUN_SG -> ('sister',)
# NOUN_SG -> ('night',)
# NOUN_SG -> ('kabaddi',)
# NOUN_SG -> ('moment',)
# NOUN_SG -> ('week',)
# NOUN_SG -> ('show',)
# NOUN_SG -> ('neighbourhood',)
# NOUN_SG -> ('sentence',)
# NOUN_SG -> ('call',)
# NOUN_SG -> ('thinking',)
# NOUN_SG -> ('morning',)
# NOUN_SG -> ('weekend',)
# NOUN_SG -> ('brother',)
# NOUN_SG -> ('book',)
# NOUN_SG -> ('cold',)
# NOUN_SG -> ('airport',)
# NOUN_SG -> ('football',)
# NOUN_SG -> ('assignment',)
# NOUN_SG -> ('outlet',)
# NOUN_SG -> ('garden',)
# NOUN_SG -> ('player',)
# NOUN_SG -> ('month',)
# NOUN_SG -> ('husband',)
# NOUN_SG -> ('mom',)
# NOUN_SG -> ('afternoon',)
# NOUN_SG -> ('car',)
# NOUN_SG -> ('picture',)
# NOUN_SG -> ('food',)
# NOUN_SG -> ('mountain',)
# NOUN_SG -> ('pilot',)
# NOUN_SG -> ('teacher',)
# NOUN_SG -> ('topper',)
# NOUN_SG -> ('friend',)
# NOUN_SG -> ('wife',)
# NOUN_SG -> ('cup',)
# NOUN_SG -> ('me',)
# NOUN_SG -> ('basketball',)
# NOUN_SG -> ('street',)
# NOUN_SG -> ('homework',)
# NOUN_SG -> ('weather',)
# NOUN_SG -> ('song',)
# NOUN_SG -> ('house',)
# NOUN_SG -> ('parcel',)
# NOUN_SG -> ('baby',)
# NOUN_PL -> ('peacocks',)
# NOUN_PL -> ('jacksons',)
# NOUN_PL -> ('emails',)
# NOUN_PL -> ('years',)
# NOUN_PL -> ('letters',)
# NOUN_PL -> ('portraits',)
# NOUN_PL -> ('weeks',)
# NOUN_PL -> ('specialists',)
# NOUN_PL -> ('boys',)
# NOUN_PL -> ('films',)
# NOUN_PL -> ('times',)
# NOUN_PL -> ('parents',)
# NOUN_PL -> ('cows',)
# NOUN_PL -> ('mountains',)
# NOUN_PL -> ('roses',)
# NOUN_PL -> ('people',)
# NOUN_PL -> ('friends',)
# NOUN_PL -> ('children',)
# NOUN_PL -> ('ages',)
# NOUN_PL -> ('goats',)
# NOUN_PL -> ('girls',)
# NOUN_PL -> ('books',)
# DET_SG -> ('a',)
# DET_SG -> ('an',)
# DET_SG -> ('this',)
# DET_SG -> ('that',)
# DET_PL -> ('no',)
# DET_PL -> ('these',)
# DET_PL -> ('many',)
# DET_PL -> ('all',)
# DET_BOTH -> ('the',)
# CONJ -> ('because',)
# CONJ -> ('but',)
# CONJ -> ('and',)
# CONJ -> ('while',)
# ADJ -> ('whole',)
# ADJ -> ('red',)
# ADJ -> ('first',)
# ADJ -> ('hungry',)
# ADJ -> ('fun',)
# ADJ -> ('two',)
# ADJ -> ('sweet',)
# ADJ -> ('three',)
# ADJ -> ('four',)
# ADJ -> ('critical',)
# ADJ -> ('terrible',)
# ADJ -> ('few',)
# ADJ -> ('delicious',)
# ADJ -> ('new',)
# ADJ -> ('last',)
# ADJ -> ('every',)
# ADJ -> ('nice',)
# ADJ -> ('severe',)
# ADJ -> ('since',)
# ADV -> ('early',)
# ADV -> ('ago',)
# ADV -> ('today',)
# ADV -> ('twice',)
# ADV -> ('heavily',)
# ADV -> ('still',)
# ADV -> ('recently',)
# ADV -> ('before',)
# ADV -> ('next',)
# ADV -> ('whereabouts',)
# ADV -> ('lately',)
# ADV -> ('never',)
# ADV -> ('always',)
# ADV -> ('very',)
# ADV -> ('already',)
# ADV -> ('tomorrow',)
# ADV -> ('yesterday',)
# ADV -> ('well',)
# ADV -> ('constantly',)
# ADV -> ('gracefully',)
# ADV -> ('past',)
# ADV -> ('not',)
# ADV -> ('when',)
# PREPOS -> ('around',)
# PREPOS -> ('in',)
# PREPOS -> ('at',)
# PREPOS -> ('as',)
# PREPOS -> ('for',)
# PREPOS -> ('by',)
# PREPOS -> ('from',)
# PREPOS -> ('down',)
# PREPOS -> ('of',)
# PREPOS -> ('far',)
# PREPOS -> ('on',)
# PREPOS -> ('to',)
# V1_SG -> ('works',)
# V1_SG -> ('teaches',)
# V1_SG -> ('am',)
# V1_SG -> ('cooks',)
# V1_SG -> ('is',)
# V1_SG -> ('climbs',)
# V1_SG -> ('plays',)
# V1_SG -> ('understands',)
# V1_SG -> ('be',)
# V1_SG -> ('know',)
# V1_SG -> ('invloves',)
# V1_SG -> ('sings',)
# V1_SG -> ('likes',)
# V1_SG -> ('draws',)
# V1_PL -> ('are',)
# V1_PL -> ('go',)
# V1_PL -> ('drink',)
# V1_PL -> ('cook',)
# V1_PL -> ('do',)
# V1_PL -> ('teach',)
# V1_PL -> ('see',)
# V1_PL -> ('think',)
# V1_PL -> ('turn',)
# V1_PL -> ('sing',)
# V1_PL -> ('rain',)
# V1_PL -> ('speak',)
# V1_PL -> ('meet',)
# V1_PL -> ('study',)
# V1_PL -> ('take',)
# V1_PL -> ('give',)
# GERUNDV -> ('seeing',)
# GERUNDV -> ('living',)
# GERUNDV -> ('suffering',)
# GERUNDV -> ('cleaning',)
# GERUNDV -> ('running',)
# GERUNDV -> ('enjoying',)
# GERUNDV -> ('having',)
# GERUNDV -> ('visiting',)
# GERUNDV -> ('ringing',)
# GERUNDV -> ('repairing',)
# GERUNDV -> ('feeling',)
# GERUNDV -> ('waiting',)
# GERUNDV -> ('dancing',)
# GERUNDV -> ('opening',)
# GERUNDV -> ('raining',)
# GERUNDV -> ('listening',)
# GERUNDV -> ('looking',)
# GERUNDV -> ('playing',)
# GERUNDV -> ('getting',)
# GERUNDV -> ('going',)
# GERUNDV -> ('snowing',)
# GERUNDV -> ('meeting',)
# GERUNDV -> ('teaching',)
# GERUNDV -> ('writing',)
# GERUNDV -> ('dating',)
# GERUNDV -> ('climbing',)
# GERUNDV -> ('spending',)
# GERUNDV -> ('taking',)
# GERUNDV -> ('studying',)
# GERUNDV -> ('burning',)
# V2 -> ('married',)
# V2 -> ('understood',)
# V2 -> ('started',)
# V2 -> ('went',)
# V2 -> ('caught',)
# V2 -> ('was',)
# V2 -> ('drink',)
# V2 -> ('would',)
# V2 -> ('tired',)
# V2 -> ('knew',)
# V2 -> ('gave',)
# V2 -> ('did',)
# V2 -> ('flew',)
# V2 -> ('read',)
# V2 -> ('made',)
# V2 -> ('received',)
# V2 -> ('taught',)
# V2 -> ('were',)
# V2 -> ('saw',)
# V3 -> ('painted',)
# V3 -> ('made',)
# V3 -> ('fed',)
# V3 -> ('written',)
# V3 -> ('done',)
# V3 -> ('given',)
# V3 -> ('gone',)
# V3 -> ('watched',)
# V3 -> ('met',)
# V3 -> ('seen',)
# V3 -> ('flown',)
# V3 -> ('acted',)
# V3 -> ('finished',)

# %% [markdown]
# ## Construction of SLR(1) Parser Table
#
# Input : English Grammar Object
#
# Output : SLR(1) Parsing table
#
#
# -> First and Follow
#
# -> Canonical collection of LR(0) items
#
# -> Building Parser table

# %%
# Generating first and follow sets

def first_follow(G) :
  def union(set1, set2):
    set1len = len(set1)
    set1 |= set2
    return set1len != len(set1)

  # initialising the data structures to store and first and follow values
  first = { symbol: set() for symbol in G.symbols }
  follow = { symbol: set() for symbol in G.symbols }

  for symbol in G.symbols :
    if symbol in G.terminals :
      first[symbol].add(symbol)
  
  follow[G.startSymbol].add('$')

  while True :
    updated = False

    for head, bodies in G.grammar.items() :
      for body in bodies :
        for symbol in body :
          if symbol != '^':
            updated |= union(first[head], first[symbol] - set('^'))
            if '^' not in first[symbol] :
              break
            else :
              updated |= union(first[head], set('^'))
        aux = follow[head]
        for symbol in reversed(body) :
          if symbol == '^':
            continue
          if symbol in follow:
            updated |= union(follow[symbol], aux - set('^'))
          if '^' in first[symbol] :
            aux = aux | first[symbol]
          else :
            aux = first[symbol]
    if not updated:
      return first, follow

# %%
# Construction of LR(0) items

# Computation of set of items constructed from I
# I - set of items for G
def CLOSURE(aug_G, I):
  J = I
  
  while True :
    item_len = len(J)
    for head, bodies in J.copy().items() :
      for body in bodies.copy():
        if '.' in body[:-1]:
          dot_pos = body.index('.')
          symbol_after_dot = body[dot_pos + 1]
          if symbol_after_dot in aug_G.nonterminals :
            for G_body in aug_G.grammar[symbol_after_dot]:
              if G_body == tuple('^'):
                J.setdefault(symbol_after_dot, set()).add(set('.'))
              else :
                J.setdefault(symbol_after_dot, set()).add(('.',) + G_body)
    if item_len == len(J):
      return J

# GOTO(I, X) defined to be the closure of the set of all items [A -> aX.b] such that [A -> a.Xb] is in I
# I - set of items
# X - grammar symbol
def GOTO(aug_G, I, X):
  goto = {}

  for head, bodies in I.items() :
    for body in bodies :
      if '.' in body[:-1]:
        dot_pos = body.index('.')
        if body[dot_pos + 1] == X :
          replaced_dot_body = body[ : dot_pos] + (X, '.') + body[dot_pos + 2: ]
          for C_head, C_bodies in CLOSURE(aug_G, {head: {replaced_dot_body}}).items():
            goto.setdefault(C_head, set()).update(C_bodies)
  
  return goto

# Construction of canonical collection of sets of LR(0) items for G'
def items(aug_G):
  C = [CLOSURE(aug_G, {aug_G.startSymbol : {('.', aug_G.startSymbol[:-1])}})]

  while True:
    item_len = len(C)
    for I in C.copy() :
      for X in aug_G.symbols:
        goto = GOTO(aug_G, I, X)
        if (len(goto) > 0) and goto not in C:
          C.append(goto)
    if item_len == len(C) :
      return C

# %%
# Construction of SLR(1) Parsing table

class SLRParser:
  def __init__(self, G):
    self.aug_G = Grammar([f"{G.startSymbol}' -> {G.startSymbol}"] + G.input)
    self.max_aug_G_len = len(max(self.aug_G.grammar, key=len))

    self.G_indexed = []
    for head, bodies in self.aug_G.grammar.items():
      for body in bodies:
        self.G_indexed.append([head, body])
    
    self.first, self.follow = first_follow(self.aug_G)

    self.C = items(self.aug_G)
    
    self.action = list(self.aug_G.terminals) + ['$']
    self.goto = []
    for nonterminal in self.aug_G.nonterminals :
      if nonterminal != self.aug_G.startSymbol :
        self.goto.append(nonterminal)
    
    self.parse_table_symbols = self.action + self.goto
    self.parse_table = self.construct_table()
  
  def construct_table(self):
    # Step 1 - Construct C
    # Step 2 - parsing actions for state i are determined
    parse_table = {r: {c: '' for c in self.parse_table_symbols} for r in range(len(self.C))}

    for i, I in enumerate(self.C) :
      for head, bodies in I.items() :
        for body in bodies :
          if '.' in body[:-1] : # Case 2a
            dot_pos = body.index('.')
            symbol_after_dot = body[dot_pos + 1]

            if symbol_after_dot in self.aug_G.terminals :
              s = f's{self.C.index(GOTO(self.aug_G, I, symbol_after_dot))}'
              if s not in parse_table[i][symbol_after_dot]:
                if 'r' in parse_table[i][symbol_after_dot] :
                  parse_table[i][symbol_after_dot] += '/'
                parse_table[i][symbol_after_dot] += s
          
          elif body[-1] == '.' and head != self.aug_G.startSymbol : # Case 2b
            for j, (G_head, G_body) in enumerate(self.G_indexed) :
              if G_head == head and (G_body == body[:-1] or G_body == ('^',) and body == ('.',)):
                for f in self.follow[head] :
                  if parse_table[i][f] :
                    parse_table[i][f] += '/'
                  parse_table[i][f] += f'r{j}'

                break

          else : # Case 2c
            parse_table[i]['$'] = 'acc'
      
      # Step 3 - Goto transistions for all nonterminals are constructed
      for A in self.aug_G.nonterminals :
        j = GOTO(self.aug_G, I, A)
        if j in self.C :
          parse_table[i][A] = self.C.index(j)

    return parse_table

  def __str__ (self) :
    def fprint(text, variable) :
      print(f'{text:>12}: {", ".join(variable)}')
    def print_line() :
      print(f'+{("-" * width + "+") * (len(list(self.aug_G.symbols) + ["$"]))}')
    def symbols_width(symbols) :
      return (width + 1) * len(symbols) - 1

    print("Augmented Grammar : ")
    for i, (head, body) in enumerate(self.G_indexed):
      print(f'{i:>{len(str(len(self.G_indexed) - 1))}}: {head:>{self.max_aug_G_len}} -> {" ".join(body)}')
    print()
    fprint('TERMINALS', self.aug_G.terminals)
    fprint('NONTERMINALS', self.aug_G.nonterminals)
    fprint('SYMBOLS', self.aug_G.symbols)

    print('\nFIRST:')
    for head in self.aug_G.grammar:
      print(f'{head:>{self.max_aug_G_len}} = {{ {", ".join(self.first[head])} }}')

    print('\nFOLLOW:')
    for head in self.aug_G.grammar:
      print(f'{head:>{self.max_aug_G_len}} = {{ {", ".join(self.follow[head])} }}')

    width = max(len(c) for c in {'ACTION'} | self.aug_G.symbols) + 2
    for r in range(len(self.C)):
      max_len = max(len(str(c)) for c in self.parse_table[r].values())

      if width < max_len + 2:
        width = max_len + 2

    print('\nPARSING TABLE:')
    print(f'+{"-" * width}+{"-" * symbols_width(self.action)}+{"-" * symbols_width(self.goto)}+')
    print(f'|{"":{width}}|{"ACTION":^{symbols_width(self.action)}}|{"GOTO":^{symbols_width(self.goto)}}|')
    print(f'|{"STATE":^{width}}+{("-" * width + "+") * len(self.parse_table_symbols)}')
    print(f'|{"":^{width}}|', end=' ')

    for symbol in self.parse_table_symbols:
      print(f'{symbol:^{width - 1}}|', end=' ')

    print()
    print_line()

    for r in range(len(self.C)):
      print(f'|{r:^{width}}|', end=' ')

      for c in self.parse_table_symbols:
        print(f'{self.parse_table[r][c]:^{width - 1}}|', end=' ')

      print()

    print_line()
    print()
    return ""

# %%
slr = SLRParser(G)
print(slr)
# Out:
# Augmented Grammar :
#   0:                   S' -> S
#   1:                    S -> NP_SG FUTURE_PERFECT S1
#   2:                    S -> S ADV
#   3:                    S -> NP_PL PAST_PERFECT_CONT S1
#   4:                    S -> NP_PL FUTURE_PERFECT S1
#   5:                    S -> NP_SG PAST_CONT_SG S1
#   6:                    S -> NP_SG FUTURE_CONT S1
#   7:                    S -> NP_PL PAST S1
#   8:                    S -> NP_PL PAST_PERFECT S1
#   9:                    S -> NP_PL FUTURE S1
#  10:                    S -> NP_PL PAST_CONT_PL S1
#  11:                    S -> NP_SG PRES_CONT_SG S1
#  12:                    S -> NP_SG FUTURE_PERFECT_CONT S1
#  13:                    S -> NP_SG PAST S1
#  14:                    S -> NP_PL PRES_CONT_PL S1
#  15:                    S -> NP_SG PRES_PERFECT_CONT_SG S1
#  16:                    S -> NP_PL PRES_PERFECT_PL S1
#  17:                    S -> NP_PL FUTURE_PERFECT_CONT S1
#  18:                    S -> NP_SG FUTURE S1
#  19:                    S -> NP_SG PAST_PERFECT S1
#  20:                    S -> NP_PL PRES_PL S1
#  21:                    S -> NP_SG PRES_PERFECT_SG S1
#  22:                    S -> NP_PL FUTURE_CONT S1
#  23:                    S -> NP_PL PRES_PERFECT_CONT_PL S1
#  24:                    S -> NP_SG PAST_PERFECT_CONT S1
#  25:                    S -> NP_SG PRES_SG S1
#  26:                   S1 -> ADV
#  27:                   S1 -> NP
#  28:                   NP -> PP
#  29:                   NP -> NP_SG
#  30:                   NP -> NP PP
#  31:                   NP -> NP_PL
#  32:                NP_SG -> DET_SG NOM_SG
#  33:                NP_SG -> PRONOUN_SG
#  34:                NP_SG -> NOM_SG
#  35:                NP_SG -> PRONOUN_SG NOM_SG
#  36:                NP_SG -> DET_BOTH NOM_SG
#  37:                NP_SG -> ADV NP_SG
#  38:                NP_SG -> PROPERNOUN
#  39:                NP_SG -> NP_SG CONJ NP
#  40:               NOM_SG -> NOM_SG NOUN_SG
#  41:               NOM_SG -> ADJ NOUN_SG
#  42:               NOM_SG -> NOUN_SG
#  43:                NP_PL -> NP_PL CONJ NP
#  44:                NP_PL -> PRONOUN_PL NOM_PL
#  45:                NP_PL -> NOM_PL
#  46:                NP_PL -> PRONOUN_PL
#  47:                NP_PL -> DET_PL NOM_PL
#  48:                NP_PL -> ADV NP_PL
#  49:                NP_PL -> DET_BOTH NOM_PL
#  50:               NOM_PL -> NOUN_PL
#  51:               NOM_PL -> ADJ NOUN_PL
#  52:               NOM_PL -> NOM_PL NOUN_PL
#  53:                   PP -> PREPOS NP_SG
#  54:                   PP -> PREPOS NP_PL
#  55:                 PAST -> V2
#  56:                 PAST -> ADV V2
#  57:         PAST_PERFECT -> had V3
#  58:         PAST_PERFECT -> had ADV V3
#  59:         PAST_CONT_SG -> was GERUNDV
#  60:         PAST_CONT_SG -> was ADV GERUNDV
#  61:         PAST_CONT_PL -> were ADV GERUNDV
#  62:         PAST_CONT_PL -> were GERUNDV
#  63:    PAST_PERFECT_CONT -> had ADV been GERUNDV
#  64:    PAST_PERFECT_CONT -> had been GERUNDV
#  65:              PRES_SG -> V1_SG
#  66:              PRES_SG -> ADV V1_SG
#  67:              PRES_PL -> V1_PL
#  68:              PRES_PL -> ADV V1_PL
#  69:      PRES_PERFECT_SG -> has ADV V3
#  70:      PRES_PERFECT_SG -> has V3
#  71:      PRES_PERFECT_PL -> have ADV V3
#  72:      PRES_PERFECT_PL -> have V3
#  73:         PRES_CONT_SG -> is ADV GERUNDV
#  74:         PRES_CONT_SG -> is GERUNDV
#  75:         PRES_CONT_PL -> are GERUNDV
#  76:         PRES_CONT_PL -> are ADV GERUNDV
#  77: PRES_PERFECT_CONT_SG -> has been GERUNDV
#  78: PRES_PERFECT_CONT_SG -> has ADV been
#  79: PRES_PERFECT_CONT_SG -> has ADV been GERUNDV
#  80: PRES_PERFECT_CONT_SG -> has been
#  81: PRES_PERFECT_CONT_PL -> have been GERUNDV
#  82: PRES_PERFECT_CONT_PL -> have ADV been GERUNDV
#  83:               FUTURE -> will V1_PL
#  84:               FUTURE -> will ADV V1_PL
#  85:       FUTURE_PERFECT -> will have V3
#  86:       FUTURE_PERFECT -> will have ADV V3
#  87:          FUTURE_CONT -> will be GERUNDV
#  88:          FUTURE_CONT -> will ADV be GERUNDV
#  89:  FUTURE_PERFECT_CONT -> will have ADV been GERUNDV
#  90:  FUTURE_PERFECT_CONT -> will have been GERUNDV
#  91:           PRONOUN_SG -> my
#  92:           PRONOUN_SG -> she
#  93:           PRONOUN_SG -> him
#  94:           PRONOUN_SG -> he
#  95:           PRONOUN_SG -> his
#  96:           PRONOUN_SG -> her
#  97:           PRONOUN_SG -> it
#  98:           PRONOUN_SG -> i
#  99:           PRONOUN_PL -> us
# 100:           PRONOUN_PL -> we
# 101:           PRONOUN_PL -> their
# 102:           PRONOUN_PL -> you
# 103:           PRONOUN_PL -> they
# 104:             RELPR_SG -> which
# 105:             RELPR_PL -> whom
# 106:           PROPERNOUN -> india
# 107:           PROPERNOUN -> germany
# 108:           PROPERNOUN -> january
# 109:           PROPERNOUN -> john
# 110:           PROPERNOUN -> ajitesh
# 111:           PROPERNOUN -> switzerland
# 112:           PROPERNOUN -> paris
# 113:           PROPERNOUN -> canada
# 114:           PROPERNOUN -> easter
# 115:           PROPERNOUN -> wednesday
# 116:           PROPERNOUN -> november
# 117:           PROPERNOUN -> joseph
# 118:           PROPERNOUN -> ishwarya
# 119:           PROPERNOUN -> america
# 120:           PROPERNOUN -> ritheesh
# 121:           PROPERNOUN -> navvya
# 122:           PROPERNOUN -> turkey
# 123:           PROPERNOUN -> may
# 124:           PROPERNOUN -> raj
# 125:              NOUN_SG -> grandfather
# 126:              NOUN_SG -> letter
# 127:              NOUN_SG -> tea
# 128:              NOUN_SG -> programming
# 129:              NOUN_SG -> fog
# 130:              NOUN_SG -> accountant
# 131:              NOUN_SG -> phone
# 132:              NOUN_SG -> airplane
# 133:              NOUN_SG -> accident
# 134:              NOUN_SG -> building
# 135:              NOUN_SG -> room
# 136:              NOUN_SG -> year
# 137:              NOUN_SG -> evening
# 138:              NOUN_SG -> movie
# 139:              NOUN_SG -> school
# 140:              NOUN_SG -> patient
# 141:              NOUN_SG -> dad
# 142:              NOUN_SG -> bed
# 143:              NOUN_SG -> pope
# 144:              NOUN_SG -> zoo
# 145:              NOUN_SG -> fire
# 146:              NOUN_SG -> album
# 147:              NOUN_SG -> milk
# 148:              NOUN_SG -> party
# 149:              NOUN_SG -> sister
# 150:              NOUN_SG -> night
# 151:              NOUN_SG -> kabaddi
# 152:              NOUN_SG -> moment
# 153:              NOUN_SG -> week
# 154:              NOUN_SG -> show
# 155:              NOUN_SG -> neighbourhood
# 156:              NOUN_SG -> sentence
# 157:              NOUN_SG -> call
# 158:              NOUN_SG -> thinking
# 159:              NOUN_SG -> morning
# 160:              NOUN_SG -> weekend
# 161:              NOUN_SG -> brother
# 162:              NOUN_SG -> book
# 163:              NOUN_SG -> cold
# 164:              NOUN_SG -> airport
# 165:              NOUN_SG -> football
# 166:              NOUN_SG -> assignment
# 167:              NOUN_SG -> outlet
# 168:              NOUN_SG -> garden
# 169:              NOUN_SG -> player
# 170:              NOUN_SG -> month
# 171:              NOUN_SG -> husband
# 172:              NOUN_SG -> mom
# 173:              NOUN_SG -> afternoon
# 174:              NOUN_SG -> car
# 175:              NOUN_SG -> picture
# 176:              NOUN_SG -> food
# 177:              NOUN_SG -> mountain
# 178:              NOUN_SG -> pilot
# 179:              NOUN_SG -> teacher
# 180:              NOUN_SG -> topper
# 181:              NOUN_SG -> friend
# 182:              NOUN_SG -> wife
# 183:              NOUN_SG -> cup
# 184:              NOUN_SG -> me
# 185:              NOUN_SG -> basketball
# 186:              NOUN_SG -> street
# 187:              NOUN_SG -> homework
# 188:              NOUN_SG -> weather
# 189:              NOUN_SG -> song
# 190:              NOUN_SG -> house
# 191:              NOUN_SG -> parcel
# 192:              NOUN_SG -> baby
# 193:              NOUN_PL -> peacocks
# 194:              NOUN_PL -> jacksons
# 195:              NOUN_PL -> emails
# 196:              NOUN_PL -> years
# 197:              NOUN_PL -> letters
# 198:              NOUN_PL -> portraits
# 199:              NOUN_PL -> weeks
# 200:              NOUN_PL -> specialists
# 201:              NOUN_PL -> boys
# 202:              NOUN_PL -> films
# 203:              NOUN_PL -> times
# 204:              NOUN_PL -> parents
# 205:              NOUN_PL -> cows
# 206:              NOUN_PL -> mountains
# 207:              NOUN_PL -> roses
# 208:              NOUN_PL -> people
# 209:              NOUN_PL -> friends
# 210:              NOUN_PL -> children
# 211:              NOUN_PL -> ages
# 212:              NOUN_PL -> goats
# 213:              NOUN_PL -> girls
# 214:              NOUN_PL -> books
# 215:               DET_SG -> a
# 216:               DET_SG -> an
# 217:               DET_SG -> this
# 218:               DET_SG -> that
# 219:               DET_PL -> no
# 220:               DET_PL -> these
# 221:               DET_PL -> many
# 222:               DET_PL -> all
# 223:             DET_BOTH -> the
# 224:                 CONJ -> because
# 225:                 CONJ -> but
# 226:                 CONJ -> and
# 227:                 CONJ -> while
# 228:                  ADJ -> whole
# 229:                  ADJ -> red
# 230:                  ADJ -> first
# 231:                  ADJ -> hungry
# 232:                  ADJ -> fun
# 233:                  ADJ -> two
# 234:                  ADJ -> sweet
# 235:                  ADJ -> three
# 236:                  ADJ -> four
# 237:                  ADJ -> critical
# 238:                  ADJ -> terrible
# 239:                  ADJ -> few
# 240:                  ADJ -> delicious
# 241:                  ADJ -> new
# 242:                  ADJ -> last
# 243:                  ADJ -> every
# 244:                  ADJ -> nice
# 245:                  ADJ -> severe
# 246:                  ADJ -> since
# 247:                  ADV -> early
# 248:                  ADV -> ago
# 249:                  ADV -> today
# 250:                  ADV -> twice
# 251:                  ADV -> heavily
# 252:                  ADV -> still
# 253:                  ADV -> recently
# 254:                  ADV -> before
# 255:                  ADV -> next
# 256:                  ADV -> whereabouts
# 257:                  ADV -> lately
# 258:                  ADV -> never
# 259:                  ADV -> always
# 260:                  ADV -> very
# 261:                  ADV -> already
# 262:                  ADV -> tomorrow
# 263:                  ADV -> yesterday
# 264:                  ADV -> well
# 265:                  ADV -> constantly
# 266:                  ADV -> gracefully
# 267:                  ADV -> past
# 268:                  ADV -> not
# 269:                  ADV -> when
# 270:               PREPOS -> around
# 271:               PREPOS -> in
# 272:               PREPOS -> at
# 273:               PREPOS -> as
# 274:               PREPOS -> for
# 275:               PREPOS -> by
# 276:               PREPOS -> from
# 277:               PREPOS -> down
# 278:               PREPOS -> of
# 279:               PREPOS -> far
# 280:               PREPOS -> on
# 281:               PREPOS -> to
# 282:                V1_SG -> works
# 283:                V1_SG -> teaches
# 284:                V1_SG -> am
# 285:                V1_SG -> cooks
# 286:                V1_SG -> is
# 287:                V1_SG -> climbs
# 288:                V1_SG -> plays
# 289:                V1_SG -> understands
# 290:                V1_SG -> be
# 291:                V1_SG -> know
# 292:                V1_SG -> invloves
# 293:                V1_SG -> sings
# 294:                V1_SG -> likes
# 295:                V1_SG -> draws
# 296:                V1_PL -> are
# 297:                V1_PL -> go
# 298:                V1_PL -> drink
# 299:                V1_PL -> cook
# 300:                V1_PL -> do
# 301:                V1_PL -> teach
# 302:                V1_PL -> see
# 303:                V1_PL -> think
# 304:                V1_PL -> turn
# 305:                V1_PL -> sing
# 306:                V1_PL -> rain
# 307:                V1_PL -> speak
# 308:                V1_PL -> meet
# 309:                V1_PL -> study
# 310:                V1_PL -> take
# 311:                V1_PL -> give
# 312:              GERUNDV -> seeing
# 313:              GERUNDV -> living
# 314:              GERUNDV -> suffering
# 315:              GERUNDV -> cleaning
# 316:              GERUNDV -> running
# 317:              GERUNDV -> enjoying
# 318:              GERUNDV -> having
# 319:              GERUNDV -> visiting
# 320:              GERUNDV -> ringing
# 321:              GERUNDV -> repairing
# 322:              GERUNDV -> feeling
# 323:              GERUNDV -> waiting
# 324:              GERUNDV -> dancing
# 325:              GERUNDV -> opening
# 326:              GERUNDV -> raining
# 327:              GERUNDV -> listening
# 328:              GERUNDV -> looking
# 329:              GERUNDV -> playing
# 330:              GERUNDV -> getting
# 331:              GERUNDV -> going
# 332:              GERUNDV -> snowing
# 333:              GERUNDV -> meeting
# 334:              GERUNDV -> teaching
# 335:              GERUNDV -> writing
# 336:              GERUNDV -> dating
# 337:              GERUNDV -> climbing
# 338:              GERUNDV -> spending
# 339:              GERUNDV -> taking
# 340:              GERUNDV -> studying
# 341:              GERUNDV -> burning
# 342:                   V2 -> married
# 343:                   V2 -> understood
# 344:                   V2 -> started
# 345:                   V2 -> went
# 346:                   V2 -> caught
# 347:                   V2 -> was
# 348:                   V2 -> drink
# 349:                   V2 -> would
# 350:                   V2 -> tired
# 351:                   V2 -> knew
# 352:                   V2 -> gave
# 353:                   V2 -> did
# 354:                   V2 -> flew
# 355:                   V2 -> read
# 356:                   V2 -> made
# 357:                   V2 -> received
# 358:                   V2 -> taught
# 359:                   V2 -> were
# 360:                   V2 -> saw
# 361:                   V3 -> painted
# 362:                   V3 -> made
# 363:                   V3 -> fed
# 364:                   V3 -> written
# 365:                   V3 -> done
# 366:                   V3 -> given
# 367:                   V3 -> gone
# 368:                   V3 -> watched
# 369:                   V3 -> met
# 370:                   V3 -> seen
# 371:                   V3 -> flown
# 372:                   V3 -> acted
# 373:                   V3 -> finished
#
#    TERMINALS: afternoon, car, tomorrow, ritheesh, cup, by, meet, snowing, today, understands, caught, dad, weather, were, raj, climbing, bed, am, zoo, we, january, you, know, ringing, sweet, opening, few, suffering, mountains, people, morning, book, us, these, yesterday, teaches, boys, turkey, seeing, ago, give, books, getting, far, ages, visiting, received, football, room, garden, watched, of, take, whom, the, down, still, taught, three, finished, november, will, always, my, mom, as, sister, that, having, read, see, had, meeting, dating, ajitesh, works, flew, parcel, looking, listening, burning, evening, twice, are, children, pilot, teacher, gone, india, accountant, phone, critical, topper, feeling, canada, living, already, seen, to, fun, america, made, they, parents, drink, album, navvya, goats, gracefully, from, this, started, done, teaching, but, moment, i, saw, tea, school, portraits, go, all, milk, friend, she, programming, never, john, first, patient, running, written, may, have, many, whole, airport, taking, is, and, think, invloves, study, airplane, year, hungry, on, sings, player, new, picture, recently, studying, weeks, climbs, rain, cows, met, be, constantly, would, an, paris, severe, not, flown, because, month, cleaning, ishwarya, last, gave, emails, painted, two, lately, has, he, waiting, cooks, their, movie, basketball, every, when, tired, baby, draws, writing, was, spending, night, early, thinking, teach, letters, kabaddi, dancing, been, it, heavily, at, house, fire, raining, playing, fog, germany, easter, terrible, married, enjoying, switzerland, his, wednesday, given, outlet, very, speak, nice, past, times, grandfather, films, peacocks, her, knew, cook, food, fed, next, me, plays, sentence, call, turn, accident, sing, years, no, him, whereabouts, well, song, week, did, acted, show, around, do, before, specialists, girls, while, jacksons, weekend, likes, homework, since, neighbourhood, letter, roses, delicious, joseph, mountain, party, wife, repairing, four, going, brother, building, red, went, a, street, which, for, assignment, husband, pope, in, friends, understood, cold
# NONTERMINALS: PAST_CONT_SG, NOUN_SG, NOM_SG, S', RELPR_SG, NOM_PL, GERUNDV, PAST_CONT_PL, DET_SG, PAST, DET_BOTH, PRONOUN_SG, PRES_PERFECT_SG, V1_PL, V3, RELPR_PL, NP, FUTURE, PROPERNOUN, FUTURE_PERFECT, PREPOS, S1, NOUN_PL, ADV, FUTURE_PERFECT_CONT, PRES_PERFECT_PL, V2, PAST_PERFECT_CONT, PRES_PERFECT_CONT_PL, V1_SG, CONJ, PP, S, PAST_PERFECT, ADJ, PRES_PL, PRES_CONT_PL, PRES_PERFECT_CONT_SG, PRES_SG, PRONOUN_PL, NP_SG, DET_PL, FUTURE_CONT, PRES_CONT_SG, NP_PL
#      SYMBOLS: PAST_CONT_SG, afternoon, car, tomorrow, by, snowing, understands, were, climbing, am, PRONOUN_SG, zoo, we, know, ringing, sweet, NP, few, PROPERNOUN, people, book, us, these, teaches, NOUN_PL, ago, V1_SG, received, room, watched, PRES_PL, PRES_CONT_PL, still, finished, three, will, as, my, mom, having, sister, that, read, see, meeting, flew, parcel, looking, listening, burning, evening, twice, are, children, teacher, india, PRES_PERFECT_SG, V1_PL, accountant, phone, critical, topper, RELPR_PL, feeling, canada, seen, FUTURE, to, america, made, they, parents, drink, goats, from, this, started, teaching, moment, saw, PRES_PERFECT_CONT_PL, CONJ, school, portraits, go, milk, never, programming, PRES_SG, john, first, DET_PL, patient, written, many, PRES_CONT_SG, is, and, invloves, airplane, year, on, DET_SG, PAST, player, studying, rain, cows, be, V3, constantly, would, an, paris, not, month, cleaning, last, FUTURE_PERFECT, gave, painted, PREPOS, two, has, waiting, cooks, movie, basketball, baby, draws, early, thinking, PRONOUN_PL, kabaddi, dancing, been, it, heavily, at, house, playing, germany, NOUN_SG, switzerland, given, outlet, very, GERUNDV, past, PAST_CONT_PL, peacocks, her, fed, food, sentence, call, accident, sing, no, song, week, acted, show, while, jacksons, V2, homework, since, delicious, party, wife, repairing, going, red, PAST_PERFECT, a, street, which, for, assignment, in, pope, understood, ritheesh, RELPR_SG, cup, meet, today, NOM_PL, caught, dad, weather, raj, bed, january, you, opening, suffering, mountains, morning, seeing, yesterday, boys, turkey, ADV, give, books, getting, far, ages, visiting, S, football, garden, of, take, whom, the, down, taught, NP_PL, november, always, NOM_SG, had, dating, ajitesh, works, DET_BOTH, pilot, gone, living, already, fun, album, S1, navvya, gracefully, done, but, i, tea, all, friend, she, PP, ADJ, running, may, have, whole, airport, taking, think, S', study, hungry, sings, new, picture, recently, weeks, climbs, met, severe, flown, because, ishwarya, emails, lately, he, their, every, tired, PAST_PERFECT_CONT, when, writing, was, spending, night, teach, letters, NP_SG, FUTURE_CONT, fire, raining, fog, easter, married, terrible, enjoying, his, wednesday, speak, nice, times, grandfather, films, knew, cook, next, me, plays, turn, years, him, whereabouts, well, did, around, do, before, specialists, girls, FUTURE_PERFECT_CONT, PRES_PERFECT_PL, weekend, likes, neighbourhood, letter, roses, joseph, mountain, four, brother, building, went, PRES_PERFECT_CONT_SG, husband, friends, cold
#
# FIRST:
#                   S' = { tomorrow, afternoon, car, zoo, we, sweet, few, people, book, us, these, ago, room, still, three, my, mom, sister, that, parcel, twice, evening, children, teacher, india, accountant, critical, phone, topper, canada, america, they, parents, goats, this, moment, school, portraits, milk, never, programming, john, first, patient, many, airplane, year, player, cows, constantly, an, not, paris, month, last, two, movie, basketball, baby, early, thinking, kabaddi, it, heavily, house, germany, switzerland, very, outlet, past, peacocks, her, food, sentence, call, accident, no, song, week, show, jacksons, homework, since, delicious, party, wife, red, a, street, assignment, pope, ritheesh, cup, today, dad, weather, raj, bed, january, you, mountains, morning, yesterday, boys, turkey, books, ages, football, garden, the, always, november, ajitesh, pilot, already, fun, album, gracefully, navvya, i, tea, all, friend, she, may, whole, airport, hungry, new, picture, recently, weeks, severe, ishwarya, emails, lately, he, their, every, when, night, letters, fire, fog, easter, terrible, his, wednesday, nice, films, grandfather, times, next, me, years, him, well, whereabouts, before, specialists, girls, weekend, neighbourhood, letter, roses, joseph, mountain, four, brother, building, husband, friends, cold }
#                    S = { tomorrow, afternoon, car, zoo, we, sweet, few, people, book, us, these, ago, room, still, three, my, mom, sister, that, parcel, twice, evening, children, teacher, india, accountant, critical, phone, topper, canada, america, they, parents, goats, this, moment, school, portraits, milk, never, programming, john, first, patient, many, airplane, year, player, cows, constantly, an, not, paris, month, last, two, movie, basketball, baby, early, thinking, kabaddi, it, heavily, house, germany, switzerland, very, outlet, past, peacocks, her, food, sentence, call, accident, no, song, week, show, jacksons, homework, since, delicious, party, wife, red, a, street, assignment, pope, ritheesh, cup, today, dad, weather, raj, bed, january, you, mountains, morning, yesterday, boys, turkey, books, ages, football, garden, the, always, november, ajitesh, pilot, already, fun, album, gracefully, navvya, i, tea, all, friend, she, may, whole, airport, hungry, new, picture, recently, weeks, severe, ishwarya, emails, lately, he, their, every, when, night, letters, fire, fog, easter, terrible, his, wednesday, nice, films, grandfather, times, next, me, years, him, well, whereabouts, before, specialists, girls, weekend, neighbourhood, letter, roses, joseph, mountain, four, brother, building, husband, friends, cold }
#                   S1 = { tomorrow, afternoon, car, by, zoo, we, sweet, few, people, book, us, these, ago, room, still, three, as, my, mom, sister, that, parcel, twice, evening, children, teacher, india, accountant, critical, phone, topper, canada, to, america, they, parents, goats, from, this, moment, school, portraits, milk, never, programming, john, first, patient, many, airplane, year, on, player, cows, constantly, not, an, paris, month, last, two, movie, basketball, baby, early, thinking, kabaddi, it, heavily, at, house, germany, switzerland, very, outlet, past, peacocks, her, food, sentence, call, accident, no, song, week, show, jacksons, homework, since, delicious, party, wife, red, a, street, for, assignment, in, pope, ritheesh, cup, today, dad, weather, raj, bed, january, you, mountains, morning, yesterday, boys, turkey, books, far, ages, football, garden, of, the, down, always, november, ajitesh, pilot, already, fun, album, gracefully, navvya, i, tea, all, friend, she, may, whole, airport, hungry, new, picture, recently, weeks, severe, ishwarya, emails, lately, he, their, every, when, night, letters, fire, fog, easter, terrible, his, wednesday, nice, films, grandfather, times, next, me, years, well, whereabouts, him, around, before, specialists, girls, weekend, neighbourhood, letter, roses, joseph, mountain, four, brother, building, husband, friends, cold }
#                   NP = { tomorrow, afternoon, car, by, zoo, we, sweet, few, people, book, us, these, ago, room, still, three, as, my, mom, sister, that, parcel, twice, evening, children, teacher, india, accountant, critical, phone, topper, canada, to, america, they, parents, goats, from, this, moment, school, portraits, milk, never, programming, john, first, patient, many, airplane, year, on, player, cows, constantly, an, not, paris, month, last, two, movie, basketball, baby, early, thinking, kabaddi, it, heavily, at, house, germany, switzerland, very, outlet, past, peacocks, her, food, sentence, call, accident, no, song, week, show, jacksons, homework, since, delicious, party, wife, red, a, street, for, assignment, in, pope, ritheesh, cup, today, dad, weather, raj, bed, january, you, mountains, morning, yesterday, boys, turkey, books, far, ages, football, garden, of, the, down, always, november, ajitesh, pilot, already, fun, album, gracefully, navvya, i, tea, all, friend, she, may, whole, airport, hungry, new, picture, recently, weeks, severe, ishwarya, emails, lately, he, their, every, when, night, letters, fire, fog, easter, terrible, his, wednesday, nice, films, grandfather, times, next, me, years, him, well, whereabouts, around, before, specialists, girls, weekend, neighbourhood, letter, roses, joseph, mountain, four, brother, building, husband, friends, cold }
#                NP_SG = { tomorrow, afternoon, car, ritheesh, cup, today, dad, weather, raj, bed, zoo, january, sweet, few, morning, book, yesterday, turkey, ago, football, room, garden, the, still, three, november, always, my, mom, sister, that, ajitesh, parcel, twice, evening, pilot, teacher, india, accountant, critical, phone, topper, canada, already, fun, america, album, gracefully, navvya, this, moment, i, tea, school, milk, friend, she, never, programming, john, first, patient, may, whole, airport, airplane, hungry, year, new, player, picture, recently, constantly, an, not, paris, severe, month, ishwarya, last, two, lately, he, movie, every, basketball, when, baby, night, early, thinking, kabaddi, it, heavily, house, fire, germany, easter, fog, terrible, switzerland, his, wednesday, very, outlet, past, nice, grandfather, her, food, next, me, sentence, call, accident, him, well, whereabouts, song, week, show, before, weekend, homework, since, neighbourhood, letter, delicious, joseph, mountain, party, wife, four, brother, building, red, a, street, assignment, husband, pope, cold }
#               NOM_SG = { afternoon, car, cup, dad, weather, bed, zoo, sweet, few, morning, book, football, room, garden, three, mom, sister, parcel, evening, pilot, teacher, accountant, critical, phone, topper, fun, album, moment, tea, school, milk, friend, programming, first, patient, whole, airport, airplane, hungry, year, new, player, picture, severe, month, last, two, movie, every, basketball, baby, night, thinking, kabaddi, house, fire, fog, terrible, outlet, nice, grandfather, food, me, sentence, call, accident, song, week, show, weekend, homework, since, neighbourhood, letter, delicious, mountain, party, wife, four, brother, building, red, street, assignment, husband, pope, cold }
#                NP_PL = { tomorrow, today, hungry, new, recently, weeks, we, cows, you, constantly, sweet, not, severe, few, last, people, mountains, emails, us, these, yesterday, two, lately, boys, ago, their, every, when, books, ages, early, letters, the, heavily, still, three, always, terrible, very, past, nice, films, times, peacocks, twice, children, next, critical, years, no, well, whereabouts, already, fun, they, parents, before, specialists, gracefully, goats, girls, jacksons, since, roses, delicious, portraits, all, never, four, red, first, many, friends, whole }
#               NOM_PL = { hungry, new, weeks, cows, sweet, severe, few, last, people, mountains, emails, two, boys, every, books, ages, letters, three, terrible, nice, films, times, peacocks, children, critical, years, fun, parents, specialists, goats, girls, jacksons, since, roses, delicious, portraits, four, red, first, friends, whole }
#                   PP = { by, from, on, far, of, for, down, to, in, at, around, as }
#                 PAST = { read, tomorrow, today, very, caught, flew, past, were, knew, twice, recently, next, well, would, whereabouts, constantly, not, did, already, made, gave, drink, yesterday, before, lately, gracefully, ago, started, tired, when, saw, was, received, never, early, went, heavily, still, taught, married, always, understood }
#         PAST_PERFECT = { had }
#         PAST_CONT_SG = { was }
#         PAST_CONT_PL = { were }
#    PAST_PERFECT_CONT = { had }
#              PRES_SG = { tomorrow, is, invloves, today, understands, very, works, past, sings, twice, am, recently, climbs, plays, next, be, know, well, whereabouts, constantly, not, already, teaches, yesterday, before, lately, gracefully, cooks, ago, likes, when, draws, never, early, heavily, still, always }
#              PRES_PL = { tomorrow, think, meet, study, see, today, very, speak, past, twice, are, cook, recently, next, rain, turn, sing, well, whereabouts, constantly, not, already, do, drink, yesterday, before, lately, gracefully, ago, give, when, go, never, early, teach, take, heavily, still, always }
#      PRES_PERFECT_SG = { has }
#      PRES_PERFECT_PL = { have }
#         PRES_CONT_SG = { is }
#         PRES_CONT_PL = { are }
# PRES_PERFECT_CONT_SG = { has }
# PRES_PERFECT_CONT_PL = { have }
#               FUTURE = { will }
#       FUTURE_PERFECT = { will }
#          FUTURE_CONT = { will }
#  FUTURE_PERFECT_CONT = { will }
#           PRONOUN_SG = { my, she, he, his, him, it, i, her }
#           PRONOUN_PL = { us, we, you, they, their }
#             RELPR_SG = { which }
#             RELPR_PL = { whom }
#           PROPERNOUN = { ritheesh, switzerland, navvya, turkey, wednesday, ajitesh, raj, joseph, india, january, canada, paris, easter, john, ishwarya, america, may, germany, november }
#              NOUN_SG = { mom, afternoon, car, sister, cup, airplane, outlet, year, dad, weather, parcel, grandfather, evening, player, bed, picture, zoo, food, pilot, teacher, me, sentence, accountant, phone, accident, call, topper, song, week, month, show, morning, book, album, weekend, movie, basketball, homework, moment, baby, neighbourhood, tea, letter, school, mountain, milk, party, night, friend, programming, thinking, wife, brother, building, football, room, garden, house, street, kabaddi, assignment, airport, patient, husband, pope, fire, fog, cold }
#              NOUN_PL = { specialists, boys, goats, girls, jacksons, books, films, times, roses, peacocks, portraits, children, ages, weeks, cows, years, letters, parents, people, friends, mountains, emails }
#               DET_SG = { that, this, a, an }
#               DET_PL = { these, no, many, all }
#             DET_BOTH = { the }
#                 CONJ = { but, because, and, while }
#                  ADJ = { two, hungry, every, nice, since, delicious, new, four, critical, red, sweet, severe, few, first, fun, last, three, whole, terrible }
#                  ADV = { tomorrow, yesterday, before, lately, gracefully, ago, today, very, past, when, twice, recently, next, never, early, well, whereabouts, constantly, not, already, heavily, still, always }
#               PREPOS = { by, from, of, for, down, on, to, in, at, far, around, as }
#                V1_SG = { teaches, is, be, know, invloves, cooks, understands, likes, climbs, works, sings, draws, am, plays }
#                V1_PL = { drink, teach, think, turn, sing, rain, meet, see, go, study, take, give, speak, are, do, cook }
#              GERUNDV = { taking, enjoying, having, waiting, snowing, meeting, teaching, dating, burning, listening, looking, getting, writing, climbing, spending, studying, visiting, repairing, going, ringing, feeling, dancing, opening, living, suffering, cleaning, running, raining, playing, seeing }
#                   V2 = { drink, read, understood, started, caught, flew, tired, were, saw, knew, was, received, went, would, did, made, taught, married, gave }
#                   V3 = { painted, met, acted, given, watched, done, flown, seen, fed, written, made, finished, gone }
#
# FOLLOW:
#                   S' = { $ }
#                    S = { tomorrow, today, very, past, twice, recently, next, $, well, whereabouts, constantly, not, already, yesterday, before, lately, gracefully, ago, when, never, early, heavily, still, always }
#                   S1 = { tomorrow, today, very, past, twice, recently, next, $, well, whereabouts, constantly, not, already, yesterday, before, lately, gracefully, ago, when, never, early, heavily, still, always }
#                   NP = { tomorrow, by, meet, today, understands, caught, were, am, $, know, teaches, yesterday, ago, give, far, received, of, take, down, still, taught, always, as, will, read, see, had, flew, works, twice, are, already, to, made, drink, gracefully, from, started, but, saw, go, never, have, is, and, think, invloves, study, on, sings, recently, climbs, rain, be, constantly, would, not, because, gave, lately, has, cooks, tired, when, draws, was, early, teach, heavily, at, married, very, speak, past, knew, cook, next, plays, turn, sing, well, whereabouts, did, around, do, before, while, likes, went, for, in, understood }
#                NP_SG = { tomorrow, by, meet, today, understands, caught, were, am, $, know, teaches, yesterday, ago, give, far, received, of, take, down, still, taught, always, will, as, read, see, had, flew, works, twice, are, already, to, made, drink, gracefully, from, started, but, saw, go, never, have, is, and, think, invloves, study, sings, on, recently, climbs, rain, be, constantly, would, not, because, gave, lately, has, cooks, tired, when, draws, was, early, teach, heavily, at, married, very, speak, past, knew, cook, next, plays, turn, sing, well, whereabouts, did, around, do, before, while, likes, went, for, in, understood }
#               NOM_SG = { tomorrow, afternoon, car, cup, by, meet, today, understands, caught, dad, weather, were, bed, am, zoo, $, know, morning, book, teaches, yesterday, ago, give, far, received, football, room, garden, of, take, down, still, taught, always, will, as, mom, read, sister, see, had, flew, works, parcel, twice, evening, are, pilot, teacher, accountant, phone, topper, already, to, made, drink, album, gracefully, from, started, but, moment, saw, tea, school, go, milk, friend, never, programming, patient, have, airport, is, and, think, invloves, study, airplane, year, sings, on, player, picture, recently, climbs, rain, be, constantly, would, not, because, month, gave, lately, has, cooks, movie, basketball, tired, when, baby, draws, was, night, early, thinking, teach, kabaddi, heavily, at, house, fire, fog, married, very, outlet, speak, past, grandfather, knew, cook, food, next, me, plays, sentence, call, turn, accident, sing, well, whereabouts, song, week, did, show, around, do, before, while, weekend, likes, homework, neighbourhood, letter, mountain, party, wife, brother, building, went, street, for, assignment, husband, pope, in, understood, cold }
#                NP_PL = { tomorrow, meet, by, today, understands, caught, were, am, $, know, teaches, yesterday, ago, give, far, received, take, of, down, still, taught, always, will, as, read, see, had, flew, works, twice, are, already, to, made, drink, gracefully, from, started, but, saw, go, never, have, and, think, is, invloves, study, on, sings, recently, climbs, rain, be, constantly, would, not, because, gave, lately, has, cooks, tired, when, draws, was, early, teach, heavily, at, married, very, speak, past, knew, cook, next, plays, turn, sing, well, whereabouts, did, around, do, before, while, likes, went, for, in, understood }
#               NOM_PL = { tomorrow, meet, by, today, understands, caught, were, am, $, know, people, mountains, teaches, yesterday, boys, ago, give, books, far, ages, received, take, of, down, still, taught, always, will, as, read, see, had, flew, works, twice, are, children, already, to, made, parents, drink, gracefully, goats, from, started, but, saw, portraits, go, never, have, and, think, is, invloves, study, on, sings, recently, weeks, rain, climbs, cows, be, constantly, would, not, because, gave, emails, lately, has, cooks, tired, when, draws, was, early, teach, letters, heavily, at, married, very, speak, past, films, times, knew, peacocks, cook, next, plays, turn, sing, years, well, whereabouts, did, around, do, before, while, specialists, girls, jacksons, likes, roses, went, for, in, friends, understood }
#                   PP = { tomorrow, by, meet, today, understands, caught, were, am, $, know, teaches, yesterday, ago, give, far, received, of, take, down, still, taught, always, will, as, read, see, had, flew, works, twice, are, already, to, made, drink, gracefully, from, started, but, saw, go, never, have, is, and, think, invloves, study, on, sings, recently, climbs, rain, be, constantly, would, not, because, gave, lately, has, cooks, tired, when, draws, was, early, teach, heavily, at, married, very, speak, past, knew, cook, next, plays, turn, sing, well, whereabouts, did, around, do, before, while, likes, went, for, in, understood }
#                 PAST = { tomorrow, afternoon, car, by, zoo, we, sweet, few, people, book, us, these, ago, room, still, three, as, my, mom, sister, that, parcel, twice, evening, children, teacher, india, accountant, critical, phone, topper, canada, to, america, they, parents, goats, from, this, moment, school, portraits, milk, never, programming, john, first, patient, many, airplane, year, on, player, cows, constantly, not, an, paris, month, last, two, movie, basketball, baby, early, thinking, kabaddi, it, heavily, at, house, germany, switzerland, very, outlet, past, peacocks, her, food, sentence, call, accident, no, song, week, show, jacksons, homework, since, delicious, party, wife, red, a, street, for, assignment, in, pope, ritheesh, cup, today, dad, weather, raj, bed, january, you, mountains, morning, yesterday, boys, turkey, books, far, ages, football, garden, of, the, down, always, november, ajitesh, pilot, already, fun, album, gracefully, navvya, i, tea, all, friend, she, may, whole, airport, hungry, new, picture, recently, weeks, severe, ishwarya, emails, lately, he, their, every, when, night, letters, fire, fog, easter, terrible, his, wednesday, nice, films, grandfather, times, next, me, years, well, whereabouts, him, around, before, specialists, girls, weekend, neighbourhood, letter, roses, joseph, mountain, four, brother, building, husband, friends, cold }
#         PAST_PERFECT = { tomorrow, afternoon, car, by, zoo, we, sweet, few, people, book, us, these, ago, room, still, three, as, my, mom, sister, that, parcel, twice, evening, children, teacher, india, accountant, critical, phone, topper, canada, to, america, they, parents, goats, from, this, moment, school, portraits, milk, never, programming, john, first, patient, many, airplane, year, on, player, cows, constantly, not, an, paris, month, last, two, movie, basketball, baby, early, thinking, kabaddi, it, heavily, at, house, germany, switzerland, very, outlet, past, peacocks, her, food, sentence, call, accident, no, song, week, show, jacksons, homework, since, delicious, party, wife, red, a, street, for, assignment, in, pope, ritheesh, cup, today, dad, weather, raj, bed, january, you, mountains, morning, yesterday, boys, turkey, books, far, ages, football, garden, of, the, down, always, november, ajitesh, pilot, already, fun, album, gracefully, navvya, i, tea, all, friend, she, may, whole, airport, hungry, new, picture, recently, weeks, severe, ishwarya, emails, lately, he, their, every, when, night, letters, fire, fog, easter, terrible, his, wednesday, nice, films, grandfather, times, next, me, years, well, whereabouts, him, around, before, specialists, girls, weekend, neighbourhood, letter, roses, joseph, mountain, four, brother, building, husband, friends, cold }
#         PAST_CONT_SG = { tomorrow, afternoon, car, by, zoo, we, sweet, few, people, book, us, these, ago, room, still, three, as, my, mom, sister, that, parcel, twice, evening, children, teacher, india, accountant, critical, phone, topper, canada, to, america, they, parents, goats, from, this, moment, school, portraits, milk, never, programming, john, first, patient, many, airplane, year, on, player, cows, constantly, not, an, paris, month, last, two, movie, basketball, baby, early, thinking, kabaddi, it, heavily, at, house, germany, switzerland, very, outlet, past, peacocks, her, food, sentence, call, accident, no, song, week, show, jacksons, homework, since, delicious, party, wife, red, a, street, for, assignment, in, pope, ritheesh, cup, today, dad, weather, raj, bed, january, you, mountains, morning, yesterday, boys, turkey, books, far, ages, football, garden, of, the, down, always, november, ajitesh, pilot, already, fun, album, gracefully, navvya, i, tea, all, friend, she, may, whole, airport, hungry, new, picture, recently, weeks, severe, ishwarya, emails, lately, he, their, every, when, night, letters, fire, fog, easter, terrible, his, wednesday, nice, films, grandfather, times, next, me, years, well, whereabouts, him, around, before, specialists, girls, weekend, neighbourhood, letter, roses, joseph, mountain, four, brother, building, husband, friends, cold }
#         PAST_CONT_PL = { tomorrow, afternoon, car, by, zoo, we, sweet, few, people, book, us, these, ago, room, still, three, as, my, mom, sister, that, parcel, twice, evening, children, teacher, india, accountant, critical, phone, topper, canada, to, america, they, parents, goats, from, this, moment, school, portraits, milk, never, programming, john, first, patient, many, airplane, year, on, player, cows, constantly, not, an, paris, month, last, two, movie, basketball, baby, early, thinking, kabaddi, it, heavily, at, house, germany, switzerland, very, outlet, past, peacocks, her, food, sentence, call, accident, no, song, week, show, jacksons, homework, since, delicious, party, wife, red, a, street, for, assignment, in, pope, ritheesh, cup, today, dad, weather, raj, bed, january, you, mountains, morning, yesterday, boys, turkey, books, far, ages, football, garden, of, the, down, always, november, ajitesh, pilot, already, fun, album, gracefully, navvya, i, tea, all, friend, she, may, whole, airport, hungry, new, picture, recently, weeks, severe, ishwarya, emails, lately, he, their, every, when, night, letters, fire, fog, easter, terrible, his, wednesday, nice, films, grandfather, times, next, me, years, well, whereabouts, him, around, before, specialists, girls, weekend, neighbourhood, letter, roses, joseph, mountain, four, brother, building, husband, friends, cold }
#    PAST_PERFECT_CONT = { tomorrow, afternoon, car, by, zoo, we, sweet, few, people, book, us, these, ago, room, still, three, as, my, mom, sister, that, parcel, twice, evening, children, teacher, india, accountant, critical, phone, topper, canada, to, america, they, parents, goats, from, this, moment, school, portraits, milk, never, programming, john, first, patient, many, airplane, year, on, player, cows, constantly, not, an, paris, month, last, two, movie, basketball, baby, early, thinking, kabaddi, it, heavily, at, house, germany, switzerland, very, outlet, past, peacocks, her, food, sentence, call, accident, no, song, week, show, jacksons, homework, since, delicious, party, wife, red, a, street, for, assignment, in, pope, ritheesh, cup, today, dad, weather, raj, bed, january, you, mountains, morning, yesterday, boys, turkey, books, far, ages, football, garden, of, the, down, always, november, ajitesh, pilot, already, fun, album, gracefully, navvya, i, tea, all, friend, she, may, whole, airport, hungry, new, picture, recently, weeks, severe, ishwarya, emails, lately, he, their, every, when, night, letters, fire, fog, easter, terrible, his, wednesday, nice, films, grandfather, times, next, me, years, well, whereabouts, him, around, before, specialists, girls, weekend, neighbourhood, letter, roses, joseph, mountain, four, brother, building, husband, friends, cold }
#              PRES_SG = { tomorrow, afternoon, car, by, zoo, we, sweet, few, people, book, us, these, ago, room, still, three, as, my, mom, sister, that, parcel, twice, evening, children, teacher, india, accountant, critical, phone, topper, canada, to, america, they, parents, goats, from, this, moment, school, portraits, milk, never, programming, john, first, patient, many, airplane, year, on, player, cows, constantly, not, an, paris, month, last, two, movie, basketball, baby, early, thinking, kabaddi, it, heavily, at, house, germany, switzerland, very, outlet, past, peacocks, her, food, sentence, call, accident, no, song, week, show, jacksons, homework, since, delicious, party, wife, red, a, street, for, assignment, in, pope, ritheesh, cup, today, dad, weather, raj, bed, january, you, mountains, morning, yesterday, boys, turkey, books, far, ages, football, garden, of, the, down, always, november, ajitesh, pilot, already, fun, album, gracefully, navvya, i, tea, all, friend, she, may, whole, airport, hungry, new, picture, recently, weeks, severe, ishwarya, emails, lately, he, their, every, when, night, letters, fire, fog, easter, terrible, his, wednesday, nice, films, grandfather, times, next, me, years, well, whereabouts, him, around, before, specialists, girls, weekend, neighbourhood, letter, roses, joseph, mountain, four, brother, building, husband, friends, cold }
#              PRES_PL = { tomorrow, afternoon, car, by, zoo, we, sweet, few, people, book, us, these, ago, room, still, three, as, my, mom, sister, that, parcel, twice, evening, children, teacher, india, accountant, critical, phone, topper, canada, to, america, they, parents, goats, from, this, moment, school, portraits, milk, never, programming, john, first, patient, many, airplane, year, on, player, cows, constantly, not, an, paris, month, last, two, movie, basketball, baby, early, thinking, kabaddi, it, heavily, at, house, germany, switzerland, very, outlet, past, peacocks, her, food, sentence, call, accident, no, song, week, show, jacksons, homework, since, delicious, party, wife, red, a, street, for, assignment, in, pope, ritheesh, cup, today, dad, weather, raj, bed, january, you, mountains, morning, yesterday, boys, turkey, books, far, ages, football, garden, of, the, down, always, november, ajitesh, pilot, already, fun, album, gracefully, navvya, i, tea, all, friend, she, may, whole, airport, hungry, new, picture, recently, weeks, severe, ishwarya, emails, lately, he, their, every, when, night, letters, fire, fog, easter, terrible, his, wednesday, nice, films, grandfather, times, next, me, years, well, whereabouts, him, around, before, specialists, girls, weekend, neighbourhood, letter, roses, joseph, mountain, four, brother, building, husband, friends, cold }
#      PRES_PERFECT_SG = { tomorrow, afternoon, car, by, zoo, we, sweet, few, people, book, us, these, ago, room, still, three, as, my, mom, sister, that, parcel, twice, evening, children, teacher, india, accountant, critical, phone, topper, canada, to, america, they, parents, goats, from, this, moment, school, portraits, milk, never, programming, john, first, patient, many, airplane, year, on, player, cows, constantly, not, an, paris, month, last, two, movie, basketball, baby, early, thinking, kabaddi, it, heavily, at, house, germany, switzerland, very, outlet, past, peacocks, her, food, sentence, call, accident, no, song, week, show, jacksons, homework, since, delicious, party, wife, red, a, street, for, assignment, in, pope, ritheesh, cup, today, dad, weather, raj, bed, january, you, mountains, morning, yesterday, boys, turkey, books, far, ages, football, garden, of, the, down, always, november, ajitesh, pilot, already, fun, album, gracefully, navvya, i, tea, all, friend, she, may, whole, airport, hungry, new, picture, recently, weeks, severe, ishwarya, emails, lately, he, their, every, when, night, letters, fire, fog, easter, terrible, his, wednesday, nice, films, grandfather, times, next, me, years, well, whereabouts, him, around, before, specialists, girls, weekend, neighbourhood, letter, roses, joseph, mountain, four, brother, building, husband, friends, cold }
# ...
# |         438          |          r79         |          r79         |          r79         |          r79         |          r79         |          r79         |                      |                      |          r79         |                      |                      |          r79         |          r79         |                      |          r79         |                      |          r79         |                      |          r79         |          r79         |          r79         |          r79         |                      |                      |          r79         |                      |          r79         |                      |          r79         |          r79         |          r79         |          r79         |          r79         |          r79         |          r79         |                      |          r79         |          r79         |                      |          r79         |                      |          r79         |                      |          r79         |          r79         |                      |                      |          r79         |          r79         |          r79         |                      |          r79         |                      |                      |          r79         |          r79         |          r79         |                      |          r79         |                      |          r79         |                      |          r79         |          r79         |          r79         |          r79         |          r79         |          r79         |                      |                      |                      |                      |                      |                      |          r79         |                      |                      |          r79         |                      |                      |                      |          r79         |          r79         |                      |          r79         |          r79         |          r79         |                      |          r79         |          r79         |          r79         |          r79         |          r79         |                      |          r79         |                      |          r79         |                      |          r79         |          r79         |          r79         |                      |          r79         |          r79         |                      |          r79         |          r79         |          r79         |          r79         |          r79         |          r79         |                      |                      |                      |                      |          r79         |          r79         |                      |          r79         |          r79         |          r79         |                      |          r79         |          r79         |          r79         |          r79         |          r79         |          r79         |          r79         |          r79         |          r79         |                      |                      |          r79         |                      |          r79         |          r79         |          r79         |                      |                      |                      |                      |                      |                      |          r79         |          r79         |          r79         |          r79         |                      |          r79         |          r79         |          r79         |          r79         |                      |          r79         |                      |                      |          r79         |                      |                      |          r79         |                      |          r79         |          r79         |          r79         |          r79         |                      |                      |          r79         |                      |          r79         |          r79         |                     ...
# |         439          |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |                      |                      |          r89         |                      |                      |          r89         |          r89         |                      |          r89         |                      |          r89         |                      |          r89         |          r89         |          r89         |          r89         |                      |                      |          r89         |                      |          r89         |                      |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |                      |          r89         |          r89         |                      |          r89         |                      |          r89         |                      |          r89         |          r89         |                      |                      |          r89         |          r89         |          r89         |                      |          r89         |                      |                      |          r89         |          r89         |          r89         |                      |          r89         |                      |          r89         |                      |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |                      |                      |                      |                      |                      |                      |          r89         |                      |                      |          r89         |                      |                      |                      |          r89         |          r89         |                      |          r89         |          r89         |          r89         |                      |          r89         |          r89         |          r89         |          r89         |          r89         |                      |          r89         |                      |          r89         |                      |          r89         |          r89         |          r89         |                      |          r89         |          r89         |                      |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |                      |                      |                      |                      |          r89         |          r89         |                      |          r89         |          r89         |          r89         |                      |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |          r89         |                      |                      |          r89         |                      |          r89         |          r89         |          r89         |                      |                      |                      |                      |                      |                      |          r89         |          r89         |          r89         |          r89         |                      |          r89         |          r89         |          r89         |          r89         |                      |          r89         |                      |                      |          r89         |                      |                      |          r89         |                      |          r89         |          r89         |          r89         |          r89         |                      |                      |          r89         |                      |          r89         |          r89         |                     ...
# +----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+----------------------+-------------------- ...

# %% [markdown]
# ## Text Pre-processing

# %%
# READING INPUT FROM FILE

inputFile = open('input.txt', 'r')
inputText = inputFile.read()
text = inputText.replace('\n', ' ')
inputFile.close()
text
# Out:
# 'She were writing a letter to Ishwarya. My teacher teaches well. She went to school. Raj is climbs a mountian. Raj plays fotball well. Mom cook delisious food. Navvya is a topper. Ishwarya is a kabbadi player. Ishwarya will sings a song in the show. These people is from Canada.'

# %%
# OUTPUT REPORT

outputLines = []
outputLines.append("ANALYSIS REPORT : \n\n")
outputLines.append("---------------------------------------------\n\n")

# %%
# SENTENCE TOKENIZATION

stop_Char=["!",".","?",";"]

sentences=[]

sentence=""
for ch in text :
  if ch not in stop_Char:
    sentence += ch
  else :
    sentence = sentence.strip()
    sentences.append(sentence)
    sentence=""  

sentenceCount = len(sentences) 
print("Sentence count : " + str(sentenceCount))

for sentence in sentences :
  print(sentence)
# Out:
# Sentence count : 10
# She were writing a letter to Ishwarya
# My teacher teaches well
# She went to school
# Raj is climbs a mountian
# Raj plays fotball well
# Mom cook delisious food
# Navvya is a topper
# Ishwarya is a kabbadi player
# Ishwarya will sings a song in the show
# These people is from Canada

# %%
# REMOVAL OF STOP CHARACTERS

reqSplChars = ["@", "&", "(", ")", "-"]
splChars = ["#", "%", "&", "^", "$", "*", "`", "+"]
punctuation = [",", ".", "!"]

exclude = splChars + punctuation
cleanSentences=[]
for sentence in sentences :
  cleantext=""
  for ch in sentence :
    if ch not in exclude:
      cleantext += ch
  cleanSentences.append(cleantext)

for cleanSentence in cleanSentences :
  print(cleanSentence)
# Out:
# She were writing a letter to Ishwarya
# My teacher teaches well
# She went to school
# Raj is climbs a mountian
# Raj plays fotball well
# Mom cook delisious food
# Navvya is a topper
# Ishwarya is a kabbadi player
# Ishwarya will sings a song in the show
# These people is from Canada

# %%
# WORD TOKENIZATION

wordsArray = []
wordsCount = []
for cleanText in cleanSentences :
  words = []
  word = ""
  i = 0
  while(i < len(cleanText)):
    if(cleanText[i] == " "):
      i += 1
    else:
      word = ""
      while(i < len(cleanText) and cleanText[i] != " "):
        word += cleanText[i]
        i += 1
      if(len(word) > 0):
        words.append(word)
  wordsArray.append(words)
  wordsCount.append(len(words))

totalWordCount = sum(wordsCount)

for i in range(sentenceCount) :
  print(wordsArray[i])
  print("Word count : " + str(wordsCount[i]))
  print()
print("Total word count : " + str(totalWordCount))
# Out:
# ['She', 'were', 'writing', 'a', 'letter', 'to', 'Ishwarya']
# Word count : 7
#
# ['My', 'teacher', 'teaches', 'well']
# Word count : 4
#
# ['She', 'went', 'to', 'school']
# Word count : 4
#
# ['Raj', 'is', 'climbs', 'a', 'mountian']
# Word count : 5
#
# ['Raj', 'plays', 'fotball', 'well']
# Word count : 4
#
# ['Mom', 'cook', 'delisious', 'food']
# Word count : 4
#
# ['Navvya', 'is', 'a', 'topper']
# Word count : 4
#
# ['Ishwarya', 'is', 'a', 'kabbadi', 'player']
# Word count : 5
#
# ['Ishwarya', 'will', 'sings', 'a', 'song', 'in', 'the', 'show']
# Word count : 8
#
# ['These', 'people', 'is', 'from', 'Canada']
# Word count : 5
#
# Total word count : 50

# %%
# Spell Check
spell = SpellChecker()
correctedWordsArray = []
misspelledCount = []
misspelledResult = []
for words in wordsArray : 
  count = 0
  misspelled = spell.unknown(words)
  
  if(len(misspelled) > 0):
    print(words)
    for word in misspelled:
        if(word not in properNouns) :
          count += 1
          print("Word : " + word)
          print("Best match : " + str(spell.correction(word)))
          print("Possible matches : " + str(spell.candidates(word)))
          misspelledResult.append("Misspelled word : {}\nBest match : {}\nPossible matches : {}\n\n".format(word, str(spell.correction(word)), str(spell.candidates(word))))
    print("Misspelled word count : " + str(count))
    misspelledCount.append(count)
    print()
    
    # Correcting the misspelled words
    correctedWords = []
    for word in words :
      if word in misspelled :
        correctedWords.append((spell.correction(word)).lower())
      else :
        correctedWords.append(word.lower())
    correctedWordsArray.append(correctedWords)
  else :
    correctedWords = [word.lower() for word in words]
    correctedWordsArray.append(correctedWords)
    print(words)
    print("Misspelled word count : " + str(len(misspelled)))
    print()
# Out:
# ['She', 'were', 'writing', 'a', 'letter', 'to', 'Ishwarya']
# Misspelled word count : 0
#
# ['My', 'teacher', 'teaches', 'well']
# Misspelled word count : 0
#
# ['She', 'went', 'to', 'school']
# Misspelled word count : 0
#
# ['Raj', 'is', 'climbs', 'a', 'mountian']
# Word : mountian
# Best match : mountain
# Possible matches : {'mountain'}
# Misspelled word count : 1
#
# ['Raj', 'plays', 'fotball', 'well']
# Word : fotball
# Best match : football
# Possible matches : {'ootball', 'fooball', 'football'}
# Misspelled word count : 1
#
# ['Mom', 'cook', 'delisious', 'food']
# Word : delisious
# Best match : delicious
# Possible matches : {'delicious', 'delirious'}
# Misspelled word count : 1
#
# ['Navvya', 'is', 'a', 'topper']
# Misspelled word count : 0
#
# ['Ishwarya', 'is', 'a', 'kabbadi', 'player']
# Word : kabbadi
# Best match : kabaddi
# Possible matches : {'kabaddi'}
# Misspelled word count : 1
#
# ['Ishwarya', 'will', 'sings', 'a', 'song', 'in', 'the', 'show']
# Misspelled word count : 0
#
# ['These', 'people', 'is', 'from', 'Canada']
# Misspelled word count : 0

# %%
totalMispelledCount = sum(misspelledCount)
print("Total misspelled words : " + str(totalMispelledCount))

print("Array of words with correct spelling : ")
for words in correctedWordsArray :
  print(words)
# Out:
# Total misspelled words : 4
# Array of words with correct spelling :
# ['she', 'were', 'writing', 'a', 'letter', 'to', 'ishwarya']
# ['my', 'teacher', 'teaches', 'well']
# ['she', 'went', 'to', 'school']
# ['raj', 'is', 'climbs', 'a', 'mountain']
# ['raj', 'plays', 'football', 'well']
# ['mom', 'cook', 'delicious', 'food']
# ['navvya', 'is', 'a', 'topper']
# ['ishwarya', 'is', 'a', 'kabaddi', 'player']
# ['ishwarya', 'will', 'sings', 'a', 'song', 'in', 'the', 'show']
# ['these', 'people', 'is', 'from', 'canada']

# %%
outputLines.append("Sentence Count : {}\n".format(sentenceCount))
outputLines.append("Word Count : {}\n".format(totalWordCount))
outputLines.append("Misspelled Count : {}\n\n".format(totalMispelledCount))
outputLines.append("---------------------------------------------\n\n")
for result in misspelledResult :
  outputLines.append(result)
outputLines.append("---------------------------------------------\n\n")

# %% [markdown]
# ## Evaluation of Grammar Correctness
#
# Input : SLR(1) Parsing table, input sentences
#
# Output : Analysis report of the input
#
#
# -> Stack implementation of input sentence
#
# -> Semantic analysis using NLP
#
# -> Genration of report

# %%
# Stack implementaion of input strings

def LR_parser(slr, w):
  isAccepted = False
  buffer = [x for x in w]
  buffer.append('$')
  pointer = 0
  a = buffer[pointer]
  stack = ['0']
  symbols = ['']
  results = {'step': [''], 'stack': ['STACK'] + stack, 'symbols': ['SYMBOLS'] + symbols, 'input': ['INPUT'], 'action': ['ACTION']}

  step = 0
  while True:
    s = int(stack[-1])
    step += 1
    results['step'].append(f'({step})')
    results['input'].append(' '.join(buffer[pointer:]))

    if a not in slr.parse_table[s]:
      results['action'].append(f'ERROR: unrecognized symbol {a}')
      isAccepted = False
      break

    elif not slr.parse_table[s][a]:
      results['action'].append('ERROR: input cannot be parsed by given grammar')
      isAccepted = False
      break

    elif '/' in slr.parse_table[s][a]:
      action = 'reduce' if slr.parse_table[s][a].count('r') > 1 else 'shift'
      results['action'].append(f'ERROR: {action}-reduce conflict at state {s}, symbol {a}')
      isAccepted = False
      break

    elif slr.parse_table[s][a].startswith('s'):
      results['action'].append('shift')
      stack.append(slr.parse_table[s][a][1:])
      symbols.append(a)
      results['stack'].append(' '.join(stack))
      results['symbols'].append(' '.join(symbols))
      pointer += 1
      a = buffer[pointer]

    elif slr.parse_table[s][a].startswith('r'):
      head, body = slr.G_indexed[int(slr.parse_table[s][a][1:])]
      results['action'].append(f'reduce by {head} -> {" ".join(body)}')

      if body != ('^',):
        stack = stack[:-len(body)]
        symbols = symbols[:-len(body)]

      stack.append(str(slr.parse_table[int(stack[-1])][head]))
      symbols.append(head)
      results['stack'].append(' '.join(stack))
      results['symbols'].append(' '.join(symbols))

    elif slr.parse_table[s][a] == 'acc':
      results['action'].append('accept')
      isAccepted = True
      break

  # Printing results
  def print_line():
    print(f'{"".join(["+" + ("-" * (max_len + 2)) for max_len in max_lens.values()])}+')

  max_lens = {key: max(len(value) for value in results[key]) for key in results}
  justs = {'step': '>', 'stack': '', 'symbols': '', 'input': '>', 'action': ''}

  print_line()
  print(''.join([f'| {history[0]:^{max_len}} ' for history, max_len in zip(results.values(), max_lens.values())]) + '|')
  print_line()
  for i, step in enumerate(results['step'][:-1], 1):
    print(''.join([f'| {history[i]:{just}{max_len}} ' for history, just, max_len in zip(results.values(), justs.values(), max_lens.values())]) + '|')

  print_line()

  return isAccepted

# %%
incorrectSentenceCount = 0
incorrectSentenceResult = []
for input_text in correctedWordsArray :
  isAccepted = LR_parser(slr, input_text)
  # Performing semantic analysis  using nlp for grammar corrections
  if(not isAccepted) :
    print("Correction : ")
    correction = GingerIt().parse(" ".join(input_text))['result']
    print(correction)
    incorrectSentenceCount += 1
    incorrectSentenceResult.append("Incorrect sentence : {}\nCorrection : {}\n\n".format(" ".join(input_text), correction))
# Out:
# +-----+-----------+-------------+-----------------------------------------+------------------------------------------------+
# |     |   STACK   |   SYMBOLS   |                  INPUT                  |                     ACTION                     |
# +-----+-----------+-------------+-----------------------------------------+------------------------------------------------+
# | (1) | 0         |             | she were writing a letter to ishwarya $ | shift                                          |
# | (2) | 0 137     |  she        |     were writing a letter to ishwarya $ | reduce by PRONOUN_SG -> she                    |
# | (3) | 0 4       |  PRONOUN_SG |     were writing a letter to ishwarya $ | reduce by NP_SG -> PRONOUN_SG                  |
# | (4) | 0 157     |  NP_SG      |     were writing a letter to ishwarya $ | shift                                          |
# | (5) | 0 157 265 |  NP_SG were |          writing a letter to ishwarya $ | ERROR: input cannot be parsed by given grammar |
# +-----+-----------+-------------+-----------------------------------------+------------------------------------------------+
# Correction :
# she was writing a letter to ishwarya
# +------+---------------+---------------------+---------------------------+--------------------------------------+
# |      |     STACK     |       SYMBOLS       |           INPUT           |                ACTION                |
# +------+---------------+---------------------+---------------------------+--------------------------------------+
# |  (1) | 0             |                     | my teacher teaches well $ | shift                                |
# |  (2) | 0 19          |  my                 |    teacher teaches well $ | reduce by PRONOUN_SG -> my           |
# |  (3) | 0 4           |  PRONOUN_SG         |    teacher teaches well $ | shift                                |
# |  (4) | 0 4 27        |  PRONOUN_SG teacher |            teaches well $ | reduce by NOUN_SG -> teacher         |
# |  (5) | 0 4 73        |  PRONOUN_SG NOUN_SG |            teaches well $ | reduce by NOM_SG -> NOUN_SG          |
# |  (6) | 0 4 189       |  PRONOUN_SG NOM_SG  |            teaches well $ | reduce by NP_SG -> PRONOUN_SG NOM_SG |
# |  (7) | 0 157         |  NP_SG              |            teaches well $ | shift                                |
# |  (8) | 0 157 268     |  NP_SG teaches      |                    well $ | reduce by V1_SG -> teaches           |
# |  (9) | 0 157 269     |  NP_SG V1_SG        |                    well $ | reduce by PRES_SG -> V1_SG           |
# | (10) | 0 157 274     |  NP_SG PRES_SG      |                    well $ | shift                                |
# | (11) | 0 157 274 173 |  NP_SG PRES_SG well |                         $ | reduce by ADV -> well                |
# | (12) | 0 157 274 338 |  NP_SG PRES_SG ADV  |                         $ | reduce by S1 -> ADV                  |
# | (13) | 0 157 274 392 |  NP_SG PRES_SG S1   |                         $ | reduce by S -> NP_SG PRES_SG S1      |
# | (14) | 0 117         |  S                  |                         $ | accept                               |
# +------+---------------+---------------------+---------------------------+--------------------------------------+
# +------+-------------------+----------------------------+----------------------+-------------------------------+
# |      |       STACK       |          SYMBOLS           |        INPUT         |            ACTION             |
# +------+-------------------+----------------------------+----------------------+-------------------------------+
# |  (1) | 0                 |                            | she went to school $ | shift                         |
# |  (2) | 0 137             |  she                       |     went to school $ | reduce by PRONOUN_SG -> she   |
# |  (3) | 0 4               |  PRONOUN_SG                |     went to school $ | reduce by NP_SG -> PRONOUN_SG |
# |  (4) | 0 157             |  NP_SG                     |     went to school $ | shift                         |
# |  (5) | 0 157 257         |  NP_SG went                |          to school $ | reduce by V2 -> went          |
# |  (6) | 0 157 228         |  NP_SG V2                  |          to school $ | reduce by PAST -> V2          |
# |  (7) | 0 157 278         |  NP_SG PAST                |          to school $ | shift                         |
# |  (8) | 0 157 278 331     |  NP_SG PAST to             |             school $ | reduce by PREPOS -> to        |
# |  (9) | 0 157 278 334     |  NP_SG PAST PREPOS         |             school $ | shift                         |
# | (10) | 0 157 278 334 40  |  NP_SG PAST PREPOS school  |                    $ | reduce by NOUN_SG -> school   |
# | (11) | 0 157 278 334 73  |  NP_SG PAST PREPOS NOUN_SG |                    $ | reduce by NOM_SG -> NOUN_SG   |
# | (12) | 0 157 278 334 124 |  NP_SG PAST PREPOS NOM_SG  |                    $ | reduce by NP_SG -> NOM_SG     |
# | (13) | 0 157 278 334 413 |  NP_SG PAST PREPOS NP_SG   |                    $ | reduce by PP -> PREPOS NP_SG  |
# | (14) | 0 157 278 344     |  NP_SG PAST PP             |                    $ | reduce by NP -> PP            |
# | (15) | 0 157 278 329     |  NP_SG PAST NP             |                    $ | reduce by S1 -> NP            |
# | (16) | 0 157 278 396     |  NP_SG PAST S1             |                    $ | reduce by S -> NP_SG PAST S1  |
# | (17) | 0 117             |  S                         |                    $ | accept                        |
# +------+-------------------+----------------------------+----------------------+-------------------------------+
# +-----+-----------+-------------+----------------------------+------------------------------------------------+
# |     |   STACK   |   SYMBOLS   |           INPUT            |                     ACTION                     |
# +-----+-----------+-------------+----------------------------+------------------------------------------------+
# | (1) | 0         |             | raj is climbs a mountain $ | shift                                          |
# | (2) | 0 105     |  raj        |     is climbs a mountain $ | reduce by PROPERNOUN -> raj                    |
# | (3) | 0 9       |  PROPERNOUN |     is climbs a mountain $ | reduce by NP_SG -> PROPERNOUN                  |
# | (4) | 0 157     |  NP_SG      |     is climbs a mountain $ | shift                                          |
# | (5) | 0 157 276 |  NP_SG is   |        climbs a mountain $ | ERROR: input cannot be parsed by given grammar |
# +-----+-----------+-------------+----------------------------+------------------------------------------------+
# Correction :
# raj climbs a mountain
# +------+---------------+-------------------------+---------------------------+---------------------------------+
# |      |     STACK     |         SYMBOLS         |           INPUT           |             ACTION              |
# +------+---------------+-------------------------+---------------------------+---------------------------------+
# |  (1) | 0             |                         | raj plays football well $ | shift                           |
# |  (2) | 0 105         |  raj                    |     plays football well $ | reduce by PROPERNOUN -> raj     |
# |  (3) | 0 9           |  PROPERNOUN             |     plays football well $ | reduce by NP_SG -> PROPERNOUN   |
# |  (4) | 0 157         |  NP_SG                  |     plays football well $ | shift                           |
# |  (5) | 0 157 292     |  NP_SG plays            |           football well $ | reduce by V1_SG -> plays        |
# |  (6) | 0 157 269     |  NP_SG V1_SG            |           football well $ | reduce by PRES_SG -> V1_SG      |
# |  (7) | 0 157 274     |  NP_SG PRES_SG          |           football well $ | shift                           |
# |  (8) | 0 157 274 118 |  NP_SG PRES_SG football |                    well $ | reduce by NOUN_SG -> football   |
# |  (9) | 0 157 274 73  |  NP_SG PRES_SG NOUN_SG  |                    well $ | reduce by NOM_SG -> NOUN_SG     |
# | (10) | 0 157 274 124 |  NP_SG PRES_SG NOM_SG   |                    well $ | reduce by NP_SG -> NOM_SG       |
# | (11) | 0 157 274 345 |  NP_SG PRES_SG NP_SG    |                    well $ | reduce by NP -> NP_SG           |
# | (12) | 0 157 274 329 |  NP_SG PRES_SG NP       |                    well $ | reduce by S1 -> NP              |
# | (13) | 0 157 274 392 |  NP_SG PRES_SG S1       |                    well $ | reduce by S -> NP_SG PRES_SG S1 |
# | (14) | 0 117         |  S                      |                    well $ | shift                           |
# | (15) | 0 117 173     |  S well                 |                         $ | reduce by ADV -> well           |
# | (16) | 0 117 200     |  S ADV                  |                         $ | reduce by S -> S ADV            |
# | (17) | 0 117         |  S                      |                         $ | accept                          |
# +------+---------------+-------------------------+---------------------------+---------------------------------+
# +-----+-------+----------+---------------------------+------------------------------------------------+
# |     | STACK | SYMBOLS  |           INPUT           |                     ACTION                     |
# +-----+-------+----------+---------------------------+------------------------------------------------+
# | (1) | 0     |          | mom cook delicious food $ | shift                                          |
# | (2) | 0 20  |  mom     |     cook delicious food $ | reduce by NOUN_SG -> mom                       |
# | (3) | 0 73  |  NOUN_SG |     cook delicious food $ | reduce by NOM_SG -> NOUN_SG                    |
# | (4) | 0 124 |  NOM_SG  |     cook delicious food $ | reduce by NP_SG -> NOM_SG                      |
# | (5) | 0 157 |  NP_SG   |     cook delicious food $ | ERROR: input cannot be parsed by given grammar |
# +-----+-------+----------+---------------------------+------------------------------------------------+
# Correction :
# mom cooks delicious food
# +------+------------------+-------------------------------+----------------------+----------------------------------+
# |      |      STACK       |            SYMBOLS            |        INPUT         |              ACTION              |
# +------+------------------+-------------------------------+----------------------+----------------------------------+
# |  (1) | 0                |                               | navvya is a topper $ | shift                            |
# |  (2) | 0 131            |  navvya                       |        is a topper $ | reduce by PROPERNOUN -> navvya   |
# |  (3) | 0 9              |  PROPERNOUN                   |        is a topper $ | reduce by NP_SG -> PROPERNOUN    |
# |  (4) | 0 157            |  NP_SG                        |        is a topper $ | shift                            |
# |  (5) | 0 157 276        |  NP_SG is                     |           a topper $ | reduce by V1_SG -> is            |
# |  (6) | 0 157 269        |  NP_SG V1_SG                  |           a topper $ | reduce by PRES_SG -> V1_SG       |
# |  (7) | 0 157 274        |  NP_SG PRES_SG                |           a topper $ | shift                            |
# |  (8) | 0 157 274 95     |  NP_SG PRES_SG a              |             topper $ | reduce by DET_SG -> a            |
# |  (9) | 0 157 274 52     |  NP_SG PRES_SG DET_SG         |             topper $ | shift                            |
# | (10) | 0 157 274 52 32  |  NP_SG PRES_SG DET_SG topper  |                    $ | reduce by NOUN_SG -> topper      |
# | (11) | 0 157 274 52 73  |  NP_SG PRES_SG DET_SG NOUN_SG |                    $ | reduce by NOM_SG -> NOUN_SG      |
# | (12) | 0 157 274 52 193 |  NP_SG PRES_SG DET_SG NOM_SG  |                    $ | reduce by NP_SG -> DET_SG NOM_SG |
# | (13) | 0 157 274 345    |  NP_SG PRES_SG NP_SG          |                    $ | reduce by NP -> NP_SG            |
# | (14) | 0 157 274 329    |  NP_SG PRES_SG NP             |                    $ | reduce by S1 -> NP               |
# | (15) | 0 157 274 392    |  NP_SG PRES_SG S1             |                    $ | reduce by S -> NP_SG PRES_SG S1  |
# | (16) | 0 117            |  S                            |                    $ | accept                           |
# +------+------------------+-------------------------------+----------------------+----------------------------------+
# +------+----------------------+--------------------------------------+--------------------------------+------------------------------------+
# |      |        STACK         |               SYMBOLS                |             INPUT              |               ACTION               |
# +------+----------------------+--------------------------------------+--------------------------------+------------------------------------+
# |  (1) | 0                    |                                      | ishwarya is a kabaddi player $ | shift                              |
# |  (2) | 0 148                |  ishwarya                            |          is a kabaddi player $ | reduce by PROPERNOUN -> ishwarya   |
# |  (3) | 0 9                  |  PROPERNOUN                          |          is a kabaddi player $ | reduce by NP_SG -> PROPERNOUN      |
# |  (4) | 0 157                |  NP_SG                               |          is a kabaddi player $ | shift                              |
# |  (5) | 0 157 276            |  NP_SG is                            |             a kabaddi player $ | reduce by V1_SG -> is              |
# |  (6) | 0 157 269            |  NP_SG V1_SG                         |             a kabaddi player $ | reduce by PRES_SG -> V1_SG         |
# |  (7) | 0 157 274            |  NP_SG PRES_SG                       |             a kabaddi player $ | shift                              |
# |  (8) | 0 157 274 95         |  NP_SG PRES_SG a                     |               kabaddi player $ | reduce by DET_SG -> a              |
# |  (9) | 0 157 274 52         |  NP_SG PRES_SG DET_SG                |               kabaddi player $ | shift                              |
# | (10) | 0 157 274 52 68      |  NP_SG PRES_SG DET_SG kabaddi        |                       player $ | reduce by NOUN_SG -> kabaddi       |
# | (11) | 0 157 274 52 73      |  NP_SG PRES_SG DET_SG NOUN_SG        |                       player $ | reduce by NOM_SG -> NOUN_SG        |
# | (12) | 0 157 274 52 193     |  NP_SG PRES_SG DET_SG NOM_SG         |                       player $ | shift                              |
# | (13) | 0 157 274 52 193 53  |  NP_SG PRES_SG DET_SG NOM_SG player  |                              $ | reduce by NOUN_SG -> player        |
# | (14) | 0 157 274 52 193 258 |  NP_SG PRES_SG DET_SG NOM_SG NOUN_SG |                              $ | reduce by NOM_SG -> NOM_SG NOUN_SG |
# | (15) | 0 157 274 52 193     |  NP_SG PRES_SG DET_SG NOM_SG         |                              $ | reduce by NP_SG -> DET_SG NOM_SG   |
# | (16) | 0 157 274 345        |  NP_SG PRES_SG NP_SG                 |                              $ | reduce by NP -> NP_SG              |
# | (17) | 0 157 274 329        |  NP_SG PRES_SG NP                    |                              $ | reduce by S1 -> NP                 |
# | (18) | 0 157 274 392        |  NP_SG PRES_SG S1                    |                              $ | reduce by S -> NP_SG PRES_SG S1    |
# | (19) | 0 117                |  S                                   |                              $ | accept                             |
# +------+----------------------+--------------------------------------+--------------------------------+------------------------------------+
# +-----+-----------+-------------+------------------------------------------+------------------------------------------------+
# |     |   STACK   |   SYMBOLS   |                  INPUT                   |                     ACTION                     |
# +-----+-----------+-------------+------------------------------------------+------------------------------------------------+
# | (1) | 0         |             | ishwarya will sings a song in the show $ | shift                                          |
# | (2) | 0 148     |  ishwarya   |          will sings a song in the show $ | reduce by PROPERNOUN -> ishwarya               |
# | (3) | 0 9       |  PROPERNOUN |          will sings a song in the show $ | reduce by NP_SG -> PROPERNOUN                  |
# | (4) | 0 157     |  NP_SG      |          will sings a song in the show $ | shift                                          |
# | (5) | 0 157 205 |  NP_SG will |               sings a song in the show $ | ERROR: input cannot be parsed by given grammar |
# +-----+-----------+-------------+------------------------------------------+------------------------------------------------+
# Correction :
# Ishwarya will sing a song in the show
# +-----+----------+-----------------+-------------------------------+------------------------------------------------+
# |     |  STACK   |     SYMBOLS     |             INPUT             |                     ACTION                     |
# +-----+----------+-----------------+-------------------------------+------------------------------------------------+
# | (1) | 0        |                 | these people is from canada $ | shift                                          |
# | (2) | 0 13     |  these          |       people is from canada $ | reduce by DET_PL -> these                      |
# | (3) | 0 47     |  DET_PL         |       people is from canada $ | shift                                          |
# | (4) | 0 47 10  |  DET_PL people  |              is from canada $ | reduce by NOUN_PL -> people                    |
# | (5) | 0 47 14  |  DET_PL NOUN_PL |              is from canada $ | reduce by NOM_PL -> NOUN_PL                    |
# | (6) | 0 47 191 |  DET_PL NOM_PL  |              is from canada $ | reduce by NP_PL -> DET_PL NOM_PL               |
# | (7) | 0 121    |  NP_PL          |              is from canada $ | ERROR: input cannot be parsed by given grammar |
# +-----+----------+-----------------+-------------------------------+------------------------------------------------+
# Correction :
# these people are from Canada

# %%
outputLines.append("Incorrect sentences count : {}\n\n".format(incorrectSentenceCount))
outputLines.append("---------------------------------------------\n\n")
for result in incorrectSentenceResult :
  outputLines.append(result)
outputLines.append("---------------------------------------------\n\n")

# %%
# WRITING RESULT TO THE OUTPUT FILE

outputFile = open("output.txt", "w")
for line in outputLines:
  outputFile.write(line)
outputFile.close()
